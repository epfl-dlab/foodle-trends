# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import numpy as np

# %%
parentDirectory = os.path.abspath(os.path.join(os.path.join(os.getcwd(), os.pardir), os.pardir))
DATA_DIR = parentDirectory +'/data/'
FIGURES_DIR = parentDirectory +'/figures/'

df = pd.read_parquet(DATA_DIR+'food_timeseries.parquet')

# %%
selected_codes = ['FR','DE','US','IT','CA','GB',
                  'ES','AU','MX','BR','IN','DK'
                  'NG','KE','EG','ID','SE','JP']
categories = list(df['category'].unique())
df = df.loc[df['name']!='Bánh mì']

# %%
weeks_2019 = list(df.iloc[:5]['ts'].apply(lambda x: pd.Series(x['max_ratio'])).iloc[0].index[:52])
weeks_2020 = list(df.iloc[:5]['ts'].apply(lambda x: pd.Series(x['max_ratio'])).iloc[0].index[52:])

# %%
items = df['mid'].unique()

# %%
list_items = []

for c,gr1 in df.groupby('category'):
    print(c)
    for item,gr2 in gr1.groupby('name'):
        gr2.loc[:,'total_2019'] = gr2['ts'].apply(lambda x: np.sum([x['max_ratio'][i] for i in weeks_2019])).copy()
        gr2.loc[:,'total_2020'] = gr2['ts'].apply(lambda x: np.sum([x['max_ratio'][i] for i in weeks_2020])).copy()
        gr2.loc[:,'total_2019_2020'] = gr2['ts'].apply(lambda x: np.sum([x['max_ratio'][i] for i in weeks_2019+weeks_2020])).copy()
        
        
        for cnt,row in gr2[['country_code','total_2019','total_2020','total_2019_2020']].iterrows():
            entry = {}
            entry['country'] = row['country_code']
            entry['category'] = c
            entry['total_2019'] = row['total_2019']
            entry['total_2020'] = row['total_2020']
            entry['total_2019_2020'] = row['total_2019_2020']
            entry['item'] = item
            list_items.append(entry)
# Out:
# beef dish
# /Users/gligoric/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/gligoric/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# bread and flatbread
# cheese
# chicken dish
# cocktail
# dessert
# egg dish
# fish dish
# fruit
# herb
# lamb dish
# pasta, pizza and noodle dish
# pastry and bakery product
# pie
# pork dish
# potato dish
# rice dish
# salad
# sandwich
# sauce
# sausage
# snack
# soft drink
# soup
# spice
# stew
# vegetable and legume
# wine, beer and liquor

# %%
df_analysis = pd.DataFrame(list_items)

# %%
for c,gr in df_analysis.groupby('category'):
    print(c)
    
    
    for country, gr2 in gr.groupby('country'):
        y1 = gr2['total_2019'].rank(ascending = True).values
        y2 = gr2['total_2020'].rank(ascending = True).values
        y3 = gr2['total_2019_2020'].rank(ascending = True).values
        if country == 'AU':
            S1 = (pd.Series( y1, index = gr2['item'].values))
            S2 = (pd.Series( y2, index = gr2['item'].values))
            S3 = (pd.Series( y3, index = gr2['item'].values))
        else:
            S1 = S1.add(pd.Series( y1, index = gr2['item'].values), fill_value = 0)
            S2 = S2.add(pd.Series( y2, index = gr2['item'].values), fill_value = 0)
            S3 = S3.add(pd.Series( y3, index = gr2['item'].values), fill_value = 0)

            
    print('average top 10 2019-2020:')
    
    my_list = [i.split('(')[0].strip() for i in (list((S3/12).dropna().sort_values().index[-10:]))[::-1]]
    my_string = ', '.join(map(str, my_list)) 
   
    print(my_string)
    
    print('\n')
    print('all sorted by volume 2019-2020:')
    
    my_list = [i.split('(')[0].strip() for i in (list((S3/12).dropna().sort_values().index))[::-1]]
    my_string = ', '.join(map(str, my_list)) 
   
    print(my_string)
    
    
    print('---------------------------------------------')
# Out:
# beef dish
# average top 10 2019-2020:
# Hamburger, Beef, Steak, Meatball, Meatloaf, Beef Stroganoff, Fajita, Beef mince, Sirloin steak, Big Mac
#
#
# all sorted by volume 2019-2020:
# Hamburger, Beef, Steak, Meatball, Meatloaf, Beef Stroganoff, Fajita, Beef mince, Sirloin steak, Big Mac, Wagyu, Kofta, Brisket, Beef tenderloin, Cheeseburger, Moussaka, Rib eye steak, Corned beef, Prosciutto, Spam, Kobe beef, Carpaccio, T-bone steak, Whopper, Pastrami, Beef bourguignon, Beef Wellington, Beef tongue, Korean barbecue, Oxtail, Yakiniku, Shabu-shabu, Chuck steak, Strip steak, Round steak, Salisbury steak, Picadillo, Rouladen, Tournedos Rossini, Beef ball, Steak and kidney pie, Motsunabe, Bistek, Horumonyaki, Stovies, Boeuf à la mode, Rollatini, Vanillerostbraten, Bò 7 món
# ---------------------------------------------
# bread and flatbread
# average top 10 2019-2020:
# Bread, Pita, Bagel, Baguette, Sourdough, Naan, Pretzel, Focaccia, Bruschetta, White bread
#
#
# all sorted by volume 2019-2020:
# Bread, Pita, Bagel, Baguette, Sourdough, Naan, Pretzel, Focaccia, Bruschetta, White bread, Brown bread, Rye bread, Flatbread, Roti, Ciabatta, Breadstick, Challah, Papadum, English muffin, Crumpet, Matzo, Bánh, Piadina, Simit, Injera, Murtabak, Kulcha, Butterbrot, Pane carasau, Bazlama, Tonis puri
# ---------------------------------------------
# cheese
# average top 10 2019-2020:
# Cheese, Mozzarella, Cream cheese, Parmigiano-Reggiano, Ricotta, Feta, Cheddar cheese, Fondue, Mascarpone, Cottage cheese
#
#
# all sorted by volume 2019-2020:
# Cheese, Mozzarella, Cream cheese, Parmigiano-Reggiano, Ricotta, Feta, Cheddar cheese, Fondue, Mascarpone, Cottage cheese, Goat cheese, Brie, Burrata, Paneer, Blue cheese, Raclette, Quark cheese, Gorgonzola, Halloumi, Camembert, Gouda cheese, Gruyère cheese, Grated cheese, Pecorino, Roquefort, Pecorino Romano, Processed cheese, Comté cheese, Swiss cheese, Stilton cheese, Monterey Jack, Khoa, Casu marzu, Asiago cheese, Stracchino, Caciocavallo, Reblochon, Romano cheese, Époisses de Bourgogne, Morbier cheese, Requeijão, Neufchâtel cheese, Oaxaca cheese, Robiola, Bryndza, Catupiry, Munster cheese, Beaufort cheese, Crottin de Chavignol, Fourme d'Ambert, Brie de Meaux, Maroilles cheese, Cheshire cheese, Tilsit cheese, Ossau-Iraty, Piave cheese, Montasio, Brocciu, Minas cheese, Cornish Yarg, Chaource cheese, Pecorino Sardo, Stinking Bishop cheese, Abondance cheese, Caerphilly cheese, Crowdie, Castelmagno, Red Windsor, Laguiole cheese, Paški sir, Sage Derby, Hushållsost, Lincolnshire Poacher cheese, Pélardon, Salers cheese, Caboc, Fourme de Montbrison, Pouligny-Saint-Pierre cheese, Casciotta d'Urbino, Bleu des Causses, Y Fenni cheese, Pecorino Siciliano, Rigotte de Condrieu, Bleu du Vercors-Sassenage, Dunlop cheese, Swaledale cheese, Pantysgawn, Tintern cheese, Bonchester cheese
# ---------------------------------------------
# fish dish
# average top 10 2019-2020:
# Tuna, Caviar, Salmon, Cod, Squid, Sardine, Catfish, Crayfish, Tempura, Smoked salmon
# all sorted by volume 2019-2020:
# Tuna, Caviar, Salmon, Cod, Squid, Sardine, Catfish, Crayfish, Tempura, Smoked salmon, Eel, Fish and chips, Anchovy, Sashimi, Ceviche, Pufferfish, Cuttlefish, Mahi-mahi, Fish finger, Stingray, Sturgeon, Marlin, Fish sauce, Haddock, Fishcake, Fugu, Surimi, Lox, California roll, Tataki, Red snapper, Fish ball, Fried prawn, Taramasalata, Crab cake, Ayu, Kedgeree, Brandade, Sakana, Acqua pazza, Chikuwa, Court-bouillon, Kabayaki, Pempek, Canh chua, Bánh canh, Ikan bakar, Cacciucco, Stargazy pie, Vorschmack, Gianchetti, Run down, Fish head curry, Amok trey, Pissalat, Schmaltz herring, Psarosoupa
# ---------------------------------------------
# fruit
# average top 10 2019-2020:
# Apple, Lemon, Pineapple, Avocado, Grape, Mango, Watermelon, Cherry, Strawberry, Banana
#
#
# all sorted by volume 2019-2020:
# Apple, Lemon, Pineapple, Avocado, Grape, Mango, Watermelon, Cherry, Strawberry, Banana, Fruit, Peach, Pomegranate, Raspberry, Pear, Papaya, Kiwifruit, Lime, Berry, Blueberry, Orange, Cranberry, Date palm, Melon, Raisin, Passion fruit, Fig, Pitaya, Apricot, Lychee, Jackfruit, Sunflower seed, Prune, Quince, Cooking plantain, Guava, Persimmon, Strawberries, Elderberry, Pomelo, Grapefruit, Key lime, Cantaloupe, Clementine, Currant, Gooseberry, Durian, Mandarin orange, Plum, Rambutan, Bitter orange, Bilberry, Honeydew, Acerola, Lingonberry, Winter melon, Chokeberry, Tomatillo, Ananas, Indian Jujube, Umeboshi, Dekopon
# ---------------------------------------------
# herb
# average top 10 2019-2020:
# Lavender, Basil, Herb, Rosemary, Celery, Coriander, Parsley, Eucalyptus, Peppermint, Liquorice
#
#
# all sorted by volume 2019-2020:
# Lavender, Basil, Herb, Rosemary, Celery, Coriander, Parsley, Eucalyptus, Peppermint, Liquorice, Dill, Common sage, Sage, Lemongrass, Chives, Thyme, Mustard plant, Lemon balm, Bay leaf, Tarragon, Caraway, Marjoram, Spearmint, Borage, English lavender, Za'atar, Galangal, Lovage, Fingerroot
# ---------------------------------------------
# lamb dish
# average top 10 2019-2020:
# Lamb and mutton, Shawarma, Doner kebab, Méchoui, Sfiha, Rogan josh, Çiğ köfte, Kokoretsi, Pasanda, Arrosticini
#
#
# all sorted by volume 2019-2020:
# Lamb and mutton, Shawarma, Doner kebab, Méchoui, Sfiha, Rogan josh, Çiğ köfte, Kokoretsi, Pasanda, Arrosticini, Kibbeh nayyeh, Jingisukan, Lechazo, Baeckeoffe, Mixiote, Tripoux, Colonial goose
# ---------------------------------------------
# pasta, pizza and noodle dish
# average top 10 2019-2020:
# Pizza, Pasta, Spaghetti, Lasagne, Noodle, Carbonara, Gnocchi, Macaroni, Penne, Ravioli
#
#
# all sorted by volume 2019-2020:
# ---------------------------------------------
# potato dish
# average top 10 2019-2020:
# French fries, Mashed potato, Gratin, Baked potato, Tortilla de patatas, Potato, Potato pancake, Sunday roast, Tater Tots, Patatas bravas
#
#
# all sorted by volume 2019-2020:
# French fries, Mashed potato, Gratin, Baked potato, Tortilla de patatas, Potato, Potato pancake, Sunday roast, Tater Tots, Patatas bravas, Kugel, Vichyssoise, Hachis Parmentier, Tartiflette, Korokke, Bonda, Frico, Nikujaga, Pommes Anna, Kopytka, Navarin, Pommes dauphine, Mince and tatties, Tombet, Himmel und Erde, Pickert, Rumbledethumps
# ---------------------------------------------
# rice dish
# average top 10 2019-2020:
# Rice, Sushi, Risotto, Fried rice, Basmati, Paella, Biryani, Bento, Pilaf, White rice
#
#
# all sorted by volume 2019-2020:
# Rice, Sushi, Risotto, Fried rice, Basmati, Paella, Biryani, Bento, Pilaf, White rice, Glutinous rice, Rice paper, Onigiri, Jasmine rice, Bibimbap, Arancini, Rice Krispies, Spanish rice, Wild rice, Rice vermicelli, Donburi, Gimbap, Kheer, Idli, Flattened rice, Arroz con pollo, Zongzi, Katsudon, Maqluba, Mujaddara, Tangyuan, Nasi lemak, Takikomi gohan, Puttu, Chazuke, Dal bhat, Tapai, Saffron rice, Arroz a la cubana, Nasi kuning, Hayashi rice, Ketupat, Nasi uduk, Kamameshi, Lemang, Panta bhat, Baji, Banana leaf rice
# ---------------------------------------------
# salad
# average top 10 2019-2020:
# Salad, Lettuce, Potato salad, Caesar salad, Pasta salad, Tabbouleh, Greek salad, Romaine lettuce, Insalata Caprese, Olivier salad
#
#
# all sorted by volume 2019-2020:
# Salad, Lettuce, Potato salad, Caesar salad, Pasta salad, Tabbouleh, Greek salad, Romaine lettuce, Insalata Caprese, Olivier salad, Egg salad, Salad Niçoise, Larb, Acar, Gado-gado, Macedonia, Curtido, Rojak, Yusheng, Israeli salad, Lalab, Kosambari, Crab Louie, Cookie salad
# ---------------------------------------------
# sandwich
# average top 10 2019-2020:
# Sandwich, Panini, Corn dog, Croque-monsieur, Tuna fish sandwich, BLT, Peanut butter and jelly sandwich, Filet-O-Fish, Bocadillo, Cucumber sandwich
#
#
# all sorted by volume 2019-2020:
# Sandwich, Panini, Corn dog, Croque-monsieur, Tuna fish sandwich, BLT, Peanut butter and jelly sandwich, Filet-O-Fish, Bocadillo, Cucumber sandwich, Vada pav, Toast Hawaii, Pan-bagnat, Croissan'wich, Breakfast roll, Sloppy joe, Barros Luco, Chow mein sandwich, Kottenbutter
# ---------------------------------------------
# sauce
# average top 10 2019-2020:
# Sauces, Mayonnaise, Pesto, Dip, Mustard, Tomato sauce, Béchamel sauce, Bolognese sauce, Soy sauce, Gravy
#
#
# all sorted by volume 2019-2020:
# Sauces, Mayonnaise, Pesto, Dip, Mustard, Tomato sauce, Béchamel sauce, Bolognese sauce, Soy sauce, Gravy, Ketchup, Hot sauce, Tahini, Salsa sauce, Balsamic vinegar, Barbecue sauce, Chutney, Vinaigrette, Aioli, Fettuccine alfredo, Hollandaise sauce, Tzatziki, Ranch dressing, Oyster sauce, Marinara sauce, Harissa, Chimichurri, Peanut sauce, Arrabbiata sauce, Mole sauce, Béarnaise sauce, Pico de gallo, Hoisin sauce, Churrasco food, Green sauce, Sofrito, Velouté sauce, Gochujang, Sweet chilli sauce, Hainanese Chicken Rice, Remoulade, Malai, Chasseur, Rouille, Brown sauce, Shacha sauce, Salmis, Sauce gribiche, Tripas, Pecel, Chả lụa, Persillade, Skordalia, Fra diavolo sauce, Sauce ravigote, Agrodolce, Beurre noir, Allemande sauce, Sauce Robert, Breton sauce
# ---------------------------------------------
# sausage
# average top 10 2019-2020:
# Sausage, Salami, Chorizo, Bratwurst, Mortadella, Black pudding, 'Nduja, Sujuk, Boudin, Andouille
#
#
# all sorted by volume 2019-2020:
# Sausage, Salami, Chorizo, Bratwurst, Mortadella, Black pudding, 'Nduja, Sujuk, Boudin, Andouille, Cumberland sausage, Knackwurst, Ventricina, Morteau sausage, Glamorgan sausage, Lincolnshire sausage
# ---------------------------------------------
# snack
# average top 10 2019-2020:
# Peanut, Popcorn, Hummus, Cashew, Tapas, Pistachio, Guacamole, Nachos, Cracker, Edamame
# all sorted by volume 2019-2020:
# Peanut, Popcorn, Hummus, Cashew, Tapas, Pistachio, Guacamole, Nachos, Cracker, Edamame, Snack food, Bhajji, Panipuri, Krupuk, Chaat, Pisang goreng, Corn nut, Klepon, Bombay mix, Leblebi
# ---------------------------------------------
# soft drink
# average top 10 2019-2020:
# Coca-Cola, Juice, Soft drink, Cola, Lemonade, Orange juice, Tonic water, Energy drink, Iced tea, Apple juice
#
#
# all sorted by volume 2019-2020:
# Coca-Cola, Juice, Soft drink, Cola, Lemonade, Orange juice, Tonic water, Energy drink, Iced tea, Apple juice, Sprite, Ginger ale, Cranberry juice, Grenadine, Tomato juice, 7 Up, Dr Pepper, Pomegranate juice, Diet Coke, Kool-Aid, Horchata, Diet soda, Cream soda, Spezi, Teh talua, Beverly, Vess
# ---------------------------------------------
# soup
# average top 10 2019-2020:
# Soup, Broth, Ramen, Miso, Pho, Hot pot, French onion soup, Goulash, Cream of mushroom soup, Minestrone
#
#
# all sorted by volume 2019-2020:
# Soup, Broth, Ramen, Miso, Pho, Hot pot, French onion soup, Goulash, Cream of mushroom soup, Minestrone, Miso soup, Gazpacho, Consommé, Pea soup, Tom yum, Noodle soup, Bisque, Laksa, Nabemono, Bird's nest soup, Hot and sour soup, Pozole, Egg drop soup, Beef noodle soup, Haleem, Menudo, Panada, Soto, Nihari, Bún bò Huế, Ribollita, Chankonabe, Zōni, Sopa de mondongo, Tinola, Taco soup, Tong sui, Butajiru, Bún riêu, Cozido, Scotch broth, Garbure, Mohinga, Olla podrida, Ching bo leung, Oille, Soup Number Five, Chakna, Sour cherry soup, Alicot, Pig's organ soup, Samlar machu
# ---------------------------------------------
# spice
# average top 10 2019-2020:
# Garlic, Table salt, Chili pepper, Ginger, Spice, Turmeric, Vanilla, Cinnamon, Common Fig, Black pepper
#
#
# all sorted by volume 2019-2020:
# Garlic, Table salt, Chili pepper, Ginger, Spice, Turmeric, Vanilla, Cinnamon, Common Fig, Black pepper, Saffron, Cumin, Oregano, Curry powder, Jalapeño, Vanilla extract, Cayenne pepper, Masala, Sambal, Habanero chili, Spice mix, Chili powder, Mustard seed, Five-spice powder, Ras el hanout, Tandoori masala, Herbes de Provence, Thai basil, Lemon pepper, Berbere, Baharat, Chaat masala, Recado rojo, Mahlab, Panch phoron, Khmeli suneli, Mitmita, Buknu
# ---------------------------------------------
# stew
# average top 10 2019-2020:
# Stew, Ratatouille, Jambalaya, Dolma, Gumbo, Sambar, Cassoulet, Blanquette de veau, Irish stew, Bigos
#
#
# all sorted by volume 2019-2020:
# Stew, Ratatouille, Jambalaya, Dolma, Gumbo, Sambar, Cassoulet, Blanquette de veau, Irish stew, Bigos, Pot-au-feu, Khash, Cholent, Fabada asturiana, Daube, Lancashire hotpot, Keşkek, Cachupa, Andrajos, Ciambotta, Hasenpfeffer, Istrian stew, Gaisburger Marsch, Ghapama
# ---------------------------------------------
# vegetable and legume
# average top 10 2019-2020:
# Vegetable, Tomato, Sweet potato, Onion, Cucumber, Spinach, Eggplant, Cauliflower, Cabbage, Asparagus
#
#
# all sorted by volume 2019-2020:
# Vegetable, Tomato, Sweet potato, Onion, Cucumber, Spinach, Eggplant, Cauliflower, Cabbage, Asparagus, Bell pepper, Pumpkin, Zucchini, Lentil, Fennel, Leek, Green bean, Artichoke, Turnip, Chickpea, Brussels sprout, Paprika, Yam, Rhubarb, Taro, Scallion, Pickled cucumber, Sauerkraut, Soybean, Mung bean, Pepperoni, Legume, Kale, Coneflower, Carrot, Leaf vegetable, Parsnip, Watercress, Horseradish, Pea, Daikon, Jerusalem artichoke, Rutabaga, Kohlrabi, Celeriac, Sorrel, Ramp, Broccoli, Water spinach, Pimiento, Radicchio, Jícama, Black gram, Poblano, Guar, Common Chickenweed, Purple Salsify, Pattypan squash, Fiddlehead fern, Ground Elder, Arracacia xanthorrhiza, Tsukemono, Chrysanthemum coronarium, Acmella oleracea, Figleaf Gourd, Winged bean, Macrotyloma uniflorum, Komatsuna, Stachys affinis, Catjang, Black Salsify, Ricebean, Sesbania grandiflora, Ullucus, Vigna aconitifolia, Tepary bean, Skirret, Chenopodium giganteum, Crithmum, Squash, Geocarpa groundnut
# ---------------------------------------------
# wine, beer and liquor
# average top 10 2019-2020:
# Wine, Vodka, Beer, Alcoholic beverage, Rum, Gin, Champagne, Tequila, Red Wine, Sake
#
#
# all sorted by volume 2019-2020:
# Wine, Vodka, Beer, Alcoholic beverage, Rum, Gin, Champagne, Tequila, Red Wine, Sake, Bourbon whiskey, Brandy, Cognac, Baileys Irish Cream, Scotch whisky, Sparkling wine, Cider, Ale, Absinthe, Sangria, Guinness, Port wine, Prosecco, Aperol, Vermouth, Mulled wine, Cabernet Sauvignon, Chardonnay, Amaretto, Moonshine, Limoncello, Budweiser, Campari, Malibu Rum, Marsala wine, Cointreau, Mirin, Mezcal, Curaçao, Jim Beam, Cachaça, Pisco, Crown Royal, Eau de vie, Mount Gay Rum, Pomace brandy
# ---------------------------------------------
