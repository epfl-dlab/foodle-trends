# %%
import pandas as pd
import numpy as np

import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math 
import seaborn as sns
import matplotlib.colors as mcolors
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from statsmodels.formula.api import mixedlm
colors = list(mcolors.TABLEAU_COLORS.keys())*2



full_names = {
    'AU': 'Australia',
    'BR': 'Brazil',
    'CA': 'Canada',
    'FR': 'France',
    'DE': 'Germany',
    'IN': 'India',
    'IT': 'Italy',
    'JP': 'Japan',
    #'KE': 'Kenia',
    'MX': 'Mexico',
    #'NG': 'Nigeria',
    'ES': 'Spain',
    'GB': 'United Kingdom',
    'US': 'United States',
}

# %%
event_dicts = [{'country': 'AU',
  'start_md_1': '2020-03-27',
  'end_md_1': '2020-06-07',
  'start_md_2': np.nan},
 {'country': 'BR',
  'start_md_1': '2020-03-23',
  'end_md_1': '2020-08-09',
  'start_md_2': np.nan},
 {'country': 'CA',
  'start_md_1': '2020-03-19',
  'end_md_1': '2020-06-21',
  'start_md_2': '2020-10-12'},
 {'country': 'DE',
  'start_md_1': '2020-03-21',
  'end_md_1': '2020-05-09',
  'start_md_2': '2020-12-18'},
 {'country': 'ES',
  'start_md_1': '2020-03-17',
  'end_md_1': '2020-06-14',
  'start_md_2': '2020-11-07'},
 {'country': 'FR',
  'start_md_1': '2020-03-18',
  'end_md_1': '2020-06-08',
  'start_md_2': '2020-11-01'},
 {'country': 'GB',
  'start_md_1': '2020-03-23',
  'end_md_1': '2020-08-03',
  'start_md_2': '2020-10-21'},
 {'country': 'IN',
  'start_md_1': '2020-03-24',
  'end_md_1': '2020-10-29',
  'start_md_2': np.nan},
 {'country': 'IT',
  'start_md_1': '2020-03-11',
  'end_md_1': '2020-06-06',
  'start_md_2': '2020-11-06'},
 {'country': 'JP',
  'start_md_1': '2020-04-12',
  'end_md_1': '2020-05-30',
  'start_md_2': np.nan},
 {'country': 'KE',
  'start_md_1': '2020-03-24',
  'end_md_1': '2020-10-04',
  'start_md_2': np.nan},
 {'country': 'MX',
  'start_md_1': '2020-03-25',
  'end_md_1': '2020-10-06',
  'start_md_2': np.nan},
 {'country': 'NG',
  'start_md_1': '2020-03-27',
  'end_md_1': '2020-08-09',
  'start_md_2': np.nan},
 {'country': 'US',
  'start_md_1': '2020-03-21',
  'end_md_1': '2020-06-11',
  'start_md_2': '2020-11-26'}]

# %%
df_events = pd.DataFrame(event_dicts)

# %%
df_events['start_md_1'] = pd.to_datetime(df_events['start_md_1'])
df_events['end_md_1'] = pd.to_datetime(df_events['end_md_1'])
df_events['start_md_2'] = pd.to_datetime(df_events['start_md_2'])

# %%
df_agg = pd.read_pickle('new_df_agg_cats.pickle')

# %%
df_agg
# Out:
#     country    category                                volume_weekly_total  \
# 0        FR     dessert  2019-01-06     903.838066
# 2019-01-13    1023.4...
# 1        FR  soft drink  2019-01-06    121.671207
# 2019-01-13    129.083...
# 2        FR   rice dish  2019-01-06    302.488958
# 2019-01-13    311.905...
# 3        FR        soup  2019-01-06    401.235196
# 2019-01-13    366.711...
# 4        FR       spice  2019-01-06    388.295133
# 2019-01-13    396.663...
# ..      ...         ...                                                ...
# 443      IN    sandwich  2019-01-06    128.525534
# 2019-01-13    108.292...
# 444      IN        cake  2019-01-06    348.050820
# 2019-01-13    317.128...
# 445      IN     sausage  2019-01-06    33.675657
# 2019-01-13    23.20636...
# 446      IN      pastry  2019-01-06    375.558105
# 2019-01-13    346.624...
# 447      IN     pudding  2019-01-06    26.152396
# 2019-01-13    18.12309...
#
#                                  volume_weekly_total_l  \
# 0    2019-01-06     815.867762
# 2019-01-13     927.2...
# 1    2019-01-06    114.391114
# 2019-01-13    121.331...
# 2    2019-01-06    278.087672
# 2019-01-13    287.005...
# 3    2019-01-06    369.185323
# 2019-01-13    337.439...
# 4    2019-01-06    355.745896
# 2019-01-13    363.625...
# ..                                                 ...
# 443  2019-01-06    119.431841
# 2019-01-13    100.167...
# 444  2019-01-06    318.301656
# 2019-01-13    289.902...
# 445  2019-01-06    31.849271
# 2019-01-13    21.87125...
# 446  2019-01-06    340.640718
# 2019-01-13    313.413...
# 447  2019-01-06    23.494133
# 2019-01-13    16.00441...
#
#                                  volume_weekly_total_h  \
# 0    2019-01-06    1001.811883
# 2019-01-13    1130.4...
# 1    2019-01-06    129.498450
# 2019-01-13    137.439...
# 2    2019-01-06    329.392011
# 2019-01-13    339.326...
# 3    2019-01-06    436.562920
# 2019-01-13    399.011...
# 4    2019-01-06    424.161427
# 2019-01-13    433.033...
# ..                                                 ...
# 443  2019-01-06    138.482397
# 2019-01-13    117.218...
# 444  2019-01-06    381.187785
# 2019-01-13    347.479...
# 445  2019-01-06    35.647279
# 2019-01-13    24.67104...
# 446  2019-01-06    414.547700
# 2019-01-13    383.746...
# 447  2019-01-06    29.236057
# 2019-01-13    20.62353...
#
#                            volume_percent_weekly_total
# 0    2019-01-06    0.086787
# 2019-01-13    0.094169
# ...
# 1    2019-01-06    0.011683
# 2019-01-13    0.011877
# ...
# 2    2019-01-06    0.029045
# 2019-01-13    0.028700
# ...
# 3    2019-01-06    0.038527
# 2019-01-13    0.033743
# ...
# 4    2019-01-06    0.037284
# 2019-01-13    0.036499
# ...
# ..                                                 ...
# 443  2019-01-06    0.007389
# 2019-01-13    0.006523
# ...
# 444  2019-01-06    0.020010
# 2019-01-13    0.019103
# ...
# 445  2019-01-06    0.001936
# 2019-01-13    0.001398
# ...
# 446  2019-01-06    0.021591
# 2019-01-13    0.020880
# ...
# 447  2019-01-06    0.001504
# 2019-01-13    0.001092
# ...
#
# [448 rows x 6 columns]

# %%
weeks_2019 = list(df_agg.iloc[0]['volume_weekly_total'].index)[:52]
weeks_2020 = list(df_agg.iloc[0]['volume_weekly_total'].index)[52:]

# %%
l = []
for cnt, row in df_agg.iterrows():
    start_md = df_events.loc[df_events['country'] == row['country']].iloc[0]['start_md_1']
    end_md = df_events.loc[df_events['country'] == row['country']].iloc[0]['end_md_1']
    start_md2 = df_events.loc[df_events['country'] == row['country']].iloc[0]['start_md_2']
    
    for week in zip(row['volume_weekly_total'].index,row['volume_weekly_total'].values,row['volume_percent_weekly_total'].values):
        
        entry = {}

        entry['country'] = row['country']
        entry['category'] = row['category']
        

        if week[0] in weeks_2020:
            date = pd.to_datetime(week[0])

            if type(start_md2)!=pd._libs.tslibs.nattype.NaTType and date > start_md2:
                continue

            entry['k'] = math.floor(((date - start_md).days +7) / 7)
            entry['volume_total'] = week[1]
            entry['volume_percent'] = week[2]
            entry['year'] = '2020'
            l.append(entry)

        elif week[0] in weeks_2019:
            date = pd.to_datetime(weeks_2020[weeks_2019.index(week[0])])
            
            if type(start_md2)!=pd._libs.tslibs.nattype.NaTType and date > start_md2:
                continue

            entry['k'] = math.floor(((date - start_md).days +7) / 7)
            entry['volume_total'] = week[1]
            entry['volume_percent'] = week[2]
            entry['year'] = '2019'
            l.append(entry)

# %%
df = pd.DataFrame(l)

# %%
#df.to_pickle('df_RDD_mobility_decrease')

# %% [markdown]
# ### Check what is the highest bandwidth we can have

# %%
df.groupby('country').agg('k').max()
# Out:
# country
# AU    40
# BR    40
# CA    30
# DE    39
# ES    33
# FR    33
# GB    30
# IN    40
# IT    34
# JP    38
# KE    40
# MX    40
# NG    40
# US    36
# Name: k, dtype: int64

# %%
df.groupby('country').agg('k').min()
# Out:
# country
# AU   -11
# BR   -11
# CA   -10
# DE   -10
# ES   -10
# FR   -10
# GB   -11
# IN   -11
# IT    -9
# JP   -13
# KE   -11
# MX   -11
# NG   -11
# US   -10
# Name: k, dtype: int64

# %%
df.groupby('country').agg('k').max().min()
# Out:
# 30

# %%
df = df.loc[(df['k'] >= -30) & (df['k'] <= 30)]

# %%
# 61 weeks, 14 countries, 32 categories

(2*30+1)*12*32*2
# Out:
# 46848

# %%
df = df.loc[(df['country'].isin(list(full_names.keys())))]

# %%
len(df)
# Out:
# 31936

# %%
df['intervention_flag'] = df['k'].apply(lambda x: 1 if x > 0 else 0)

# %%
df.head()
# Out:
#   country category   k  volume_total  volume_percent  year  intervention_flag
# 0      FR  dessert -10    903.838066        0.086787  2019                  0
# 1      FR  dessert  -9   1023.422689        0.094169  2019                  0
# 2      FR  dessert  -8   1176.977692        0.104344  2019                  0
# 3      FR  dessert  -7   1814.685271        0.154947  2019                  0
# 4      FR  dessert  -6   1524.969131        0.133130  2019                  0

# %%
def generate_equation(order):
    if order == 'Cubic':
        eq = "volume_total ~ intervention_flag*k*year + intervention_flag*np.power(k,2)*year + intervention_flag*np.power(k,3)*year"
    elif order == "Quadratic":
        eq = "volume_total ~ intervention_flag*k*year + intervention_flag*np.power(k,2)*year"
    elif order == "Linear":
        eq = "volume_total ~ intervention_flag*k*year"
    elif order == 'Constant':
        eq = "volume_total ~ intervention_flag*year"
    return eq

# %%
import matplotlib.pyplot as mpl
mpl.rcParams['font.size'] = 12

fig, axes = plt.subplots(2,2, figsize = (10,10), sharey = True)


for model in ['Constant','Linear','Quadratic','Cubic']:
    
    point = []
    conf = []
        
    k = 30
    
    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k)].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

    mod = smf.ols(generate_equation(model), 
                  data = df_temp)

    res = mod.fit(cov_type='hc0')
 
    if model == 'Constant':
        sbplt = axes[0,0]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+'*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '')
        
    elif model == 'Linear':
        sbplt = axes[0,1]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+('*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '') +
                        ', β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:k:year[T.2020]']<0.05 else '') )

    elif model == 'Quadratic':
        sbplt = axes[1,0]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+('*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '')+ 
                        ', β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:k:year[T.2020]']<0.05 else '')+
                        ', γ='+str(round(res.params['intervention_flag:np.power(k, 2):year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 2):year[T.2020]']<0.05 else ''))

    else:
        sbplt = axes[1,1]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+('*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '')+ 
                        ', β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:k:year[T.2020]']<0.05 else '') +
                        ', γ='+str(round(res.params['intervention_flag:np.power(k, 2):year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 2):year[T.2020]']<0.05 else '') +
                        ', δ='+str(round(res.params['intervention_flag:np.power(k, 3):year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 3):year[T.2020]']<0.05 else ''))

    
    sbplt.vlines(0.5,5,7.5, linestyle = '--')

    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k) & (df['year'] == '2020')].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)
    
    sbplt.scatter(df_temp['k'].values,df_temp['volume_total'].values, color = 'tab:orange')
    sbplt.fill_between(df_temp['k'].values,res.get_prediction(df_temp).conf_int()[:,0],
                 res.get_prediction(df_temp).conf_int()[:,1], alpha = 0.3, color = 'gray')

    sbplt.plot(df_temp['k'].values,res.get_prediction(df_temp).predicted_mean, color = 'tab:orange', label = '2020')

    
    
    
    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k) & (df['year'] == '2019')].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)
    
    sbplt.scatter(df_temp['k'].values,df_temp['volume_total'].values, color = 'tab:blue')
    sbplt.fill_between(df_temp['k'].values,res.get_prediction(df_temp).conf_int()[:,0],
                 res.get_prediction(df_temp).conf_int()[:,1], alpha = 0.3, color = 'gray')

    sbplt.plot(df_temp['k'].values,res.get_prediction(df_temp).predicted_mean, color = 'tab:blue', label = '2019')


    sbplt.legend()

    sbplt.set_xlabel('k')
    


    #sbplt.set_xticks(range(0,31)[::5])
    #sbplt.set_xticklabels(range(0,31)[::5])
    sbplt.set_xlim([-32,32])
    #sbplt.set_xlabel('Bandwidth (± weeks around intervention)')
    sbplt.set_ylabel('Estimated log total volume')
    #sbplt.set_ylim([-1.5,2.5])

plt.tight_layout()

fig.suptitle('Italy, bread and flatbread, bandwidth K=10', position = (0.5,1.05), fontsize= 15)
# Out:
# Text(0.5, 1.05, 'Italy, bread and flatbread, bandwidth K=10')

# %%
import matplotlib.pyplot as mpl
mpl.rcParams['font.size'] = 12

fig, axes = plt.subplots(2,2, figsize = (10,10), sharey = True)


for model in ['Constant','Linear','Quadratic','Cubic']:
    
    point = []
    conf = []
        
    k = 10
    
    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k)].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

    mod = smf.ols(generate_equation(model), 
                  data = df_temp)

    res = mod.fit(cov_type='hc0')
 
    if model == 'Constant':
        sbplt = axes[0,0]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+'*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '')
        
    elif model == 'Linear':
        sbplt = axes[0,1]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+('*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '') +
                        ', β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:k:year[T.2020]']<0.05 else '') )

    elif model == 'Quadratic':
        sbplt = axes[1,0]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+('*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '')+ 
                        ', β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:k:year[T.2020]']<0.05 else '')+
                        ', γ='+str(round(res.params['intervention_flag:np.power(k, 2):year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 2):year[T.2020]']<0.05 else ''))

    else:
        sbplt = axes[1,1]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+('*' if res.pvalues['intervention_flag:year[T.2020]']<0.05 else '')+ 
                        ', β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:k:year[T.2020]']<0.05 else '') +
                        ', γ='+str(round(res.params['intervention_flag:np.power(k, 2):year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 2):year[T.2020]']<0.05 else '') +
                        ', δ='+str(round(res.params['intervention_flag:np.power(k, 3):year[T.2020]'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 3):year[T.2020]']<0.05 else ''))

    
    sbplt.vlines(0.5,5,7.5, linestyle = '--')

    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k) & (df['year'] == '2020')].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)
    
    sbplt.scatter(df_temp['k'].values,df_temp['volume_total'].values, color = 'tab:orange')
    sbplt.fill_between(df_temp['k'].values,res.get_prediction(df_temp).conf_int()[:,0],
                 res.get_prediction(df_temp).conf_int()[:,1], alpha = 0.3, color = 'gray')

    sbplt.plot(df_temp['k'].values,res.get_prediction(df_temp).predicted_mean, color = 'tab:orange', label = '2020')

    
    
    
    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k) & (df['year'] == '2019')].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)
    
    sbplt.scatter(df_temp['k'].values,df_temp['volume_total'].values, color = 'tab:blue')
    sbplt.fill_between(df_temp['k'].values,res.get_prediction(df_temp).conf_int()[:,0],
                 res.get_prediction(df_temp).conf_int()[:,1], alpha = 0.3, color = 'gray')

    sbplt.plot(df_temp['k'].values,res.get_prediction(df_temp).predicted_mean, color = 'tab:blue', label = '2019')


    sbplt.legend()

    sbplt.set_xlabel('k')
    


    #sbplt.set_xticks(range(0,31)[::5])
    #sbplt.set_xticklabels(range(0,31)[::5])
    sbplt.set_xlim([-32,32])
    #sbplt.set_xlabel('Bandwidth (± weeks around intervention)')
    sbplt.set_ylabel('Estimated log total volume')
    #sbplt.set_ylim([-1.5,2.5])

plt.tight_layout()

fig.suptitle('Italy, bread and flatbread, bandwidth K=10', position = (0.5,1.05), fontsize= 15)
# Out:
# Text(0.5, 1.05, 'Italy, bread and flatbread, bandwidth K=10')

# %%
import matplotlib.pyplot as mpl
mpl.rcParams['font.size'] = 12

fig, axes = plt.subplots(2,2, figsize = (10,10), sharey = True)


for model in ['Constant','Linear','Quadratic','Cubic']:
    
    point = []
    conf = []
        
    for k in range(3,31):
    
        df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                    (df['country'] == 'IT') & \
                                    (df['k'] >= -k) & (df['k'] <= k)].copy()
        
        df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

        mod = smf.ols(generate_equation(model), 
                      data = df_temp)

        res = mod.fit(cov_type='hc0')
        
    
        if model == 'Cubic':
            point.append([res.params['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]'], res.params['intervention_flag:np.power(k, 3):year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]'], res.params['intervention_flag:np.power(k, 3):year[T.2020]']])
        elif model == "Quadratic":
            point.append([res.params['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]']])
        elif model == "Linear":
            point.append([res.params['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]']])
        elif model == 'Constant':
            point.append([res.params['intervention_flag:year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]']])
            
    if model == 'Constant':
        sbplt = axes[0,0]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31),
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]), 
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
        idmax = np.argmax(np.array([i[0] for i in point]))
        sbplt.vlines(range(3,31)[idmax],-1.5,2.5, alpha = 0.5, color = 'tab:red', label = 'max α='+str(round(np.max(np.array([i[0] for i in point])),2)))
        
    elif model == 'Linear':
        sbplt = axes[0,1]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]),
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
        
        sbplt.plot(range(3,31), [i[1] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[1] for i in point]) - 2*np.array([i[1] for i in conf]),
                           np.array([i[1] for i in point]) + 2*np.array([i[1] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'β')
        idmax = np.argmax(np.array([i[0] for i in point]))
        sbplt.vlines(range(3,31)[idmax],-1.5,2.5, alpha = 0.5, color = 'tab:red', label = 'max α='+str(round(np.max(np.array([i[0] for i in point])),2)))
        
    elif model == 'Quadratic':
        sbplt = axes[1,0]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31),
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]), 
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
        
        sbplt.plot(range(3,31), [i[1] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[1] for i in point]) - 2*np.array([i[1] for i in conf]),
                           np.array([i[1] for i in point]) + 2*np.array([i[1] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'β')
    
        sbplt.plot(range(3,31), [i[2] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[2] for i in point]) - 2*np.array([i[2] for i in conf]),
                           np.array([i[2] for i in point]) + 2*np.array([i[2] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'γ')
    
    else:
        sbplt = axes[1,1]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31),
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]), 
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
       
        sbplt.plot(range(3,31), [i[1] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[1] for i in point]) - 2*np.array([i[1] for i in conf]),
                           np.array([i[1] for i in point]) + 2*np.array([i[1] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'β')
        
        sbplt.plot(range(3,31), [i[2] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[2] for i in point]) - 2*np.array([i[2] for i in conf]),
                           np.array([i[2] for i in point]) + 2*np.array([i[2] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'γ')
        
        sbplt.plot(range(3,31), [i[3] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[3] for i in point]) - 2*np.array([i[3] for i in conf]),
                           np.array([i[3] for i in point]) + 2*np.array([i[3] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'δ')
    
    
    sbplt.set_title(model)
    sbplt.legend(loc = "upper right")
    sbplt.hlines(0,0,30, linestyle = '--')
    sbplt.set_xticks(range(0,31)[::5])
    sbplt.set_xticklabels(range(0,31)[::5])
    sbplt.set_xlim([-1,31])
    sbplt.set_xlabel('Bandwidth (± weeks around intervention)')
    sbplt.set_ylabel('Multiplicative effect')
    sbplt.set_ylim([-1.5,2.5])

plt.tight_layout()

fig.suptitle('Italy, bread and flatbread', position = (0.5,1.05), fontsize= 15)
# Out:
# Text(0.5, 1.05, 'Italy, bread and flatbread')

# %% [markdown]
# ### How to include all countries?

# %%
cats = ['dessert', 'soft drink', 'rice dish', 'soup', 'spice',
       'chicken dish', 'fish dish', 'fruit', 'cheese', 'pork dish',
       'vegetable', 'lamb dish', 'herb', 'confection', 'snack',
       'beef dish', 'liquor', 'pie', 'pasta and noodle dish',
       'bread and flatbread', 'chocolate bar', 'potato dish', 'stew',
       'egg dish', 'sauce', 'cocktail', 'salad', 'sandwich', 'cake',
       'sausage', 'pastry', 'pudding']

# %%
len(cats)
# Out:
# 32

# %%
import matplotlib.pyplot as mpl
mpl.rcParams['font.size'] = 12




fig, axes = plt.subplots(2,2, figsize = (10,10), sharey = True)


for model in ['Constant','Linear','Quadratic','Cubic']:
    
    point = []
    conf = []
        
    k = 30
    
    df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                #(df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k)].copy()

    df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

    mod = smf.ols(generate_equation(model), 
                  data = df_temp)

    res = mod.fit(cov_type='hc0')

    if model == 'Constant':
        sbplt = axes[0,0]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag'],2))+'*' if res.pvalues['intervention_flag']<0.05 else '')
        
    elif model == 'Linear':
        sbplt = axes[0,1]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag'],2))+('*' if res.pvalues['intervention_flag']<0.05 else '') +
                        ', β='+str(round(res.params['intervention_flag:k'],2)) + ('*' if res.pvalues['intervention_flag:k']<0.05 else '') )

    elif model == 'Quadratic':
        sbplt = axes[1,0]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag'],2))+('*' if res.pvalues['intervention_flag']<0.05 else '')+ 
                        ', β='+str(round(res.params['intervention_flag:k'],2)) + ('*' if res.pvalues['intervention_flag:k']<0.05 else '')+
                        ', γ='+str(round(res.params['intervention_flag:np.power(k, 2)'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 2)']<0.05 else ''))

    else:
        sbplt = axes[1,1]
        sbplt.set_title(model+'\n α='+str(round(res.params['intervention_flag'],2))+('*' if res.pvalues['intervention_flag']<0.05 else '')+ 
                        ', β='+str(round(res.params['intervention_flag:k'],2)) + ('*' if res.pvalues['intervention_flag:k']<0.05 else '') +
                        ', γ='+str(round(res.params['intervention_flag:np.power(k, 2)'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 2)']<0.05 else '') +
                        ', δ='+str(round(res.params['intervention_flag:np.power(k, 3)'],2)) + ('*' if res.pvalues['intervention_flag:np.power(k, 3)']<0.05 else ''))

    #sbplt.scatter(df_temp['k'].values,df_temp['volume_total'].values, color = 'black')
    sbplt.vlines(0.5,5,7, linestyle = '--')

    
    
    sbplt.fill_between(df_temp['k'].values[:k+1],res.get_prediction(df_temp).conf_int()[:,0][:k+1],
                 res.get_prediction(df_temp).conf_int()[:,1][:k+1], alpha = 0.3, color = 'gray')

    sbplt.plot(df_temp['k'].values[:k+1],res.get_prediction(df_temp).predicted_mean[:k+1], color = 'black')
    
    sbplt.fill_between(df_temp['k'].values[k+1:2*k+1],res.get_prediction(df_temp).conf_int()[:,0][k+1:2*k+1],
                 res.get_prediction(df_temp).conf_int()[:,1][k+1:2*k+1], alpha = 0.3, color = 'gray')

    sbplt.plot(df_temp['k'].values[k+1:2*k+1],res.get_prediction(df_temp).predicted_mean[k+1:2*k+1], color = 'black')
    
    
    #sbplt.fill_between(df_temp['k'].values[:k+1],res.get_prediction(df_temp).conf_int()[:,0][:k+1],
    #             res.get_prediction(df_temp).conf_int()[:,1][:k+1], alpha = 0.3, color = 'gray')

    #sbplt.plot(df_temp['k'].values[:k+1],res.get_prediction(df_temp).predicted_mean[:k+1], color = 'black')

    #sbplt.fill_between(df_temp['k'].values[-k:],res.get_prediction(df_temp).conf_int()[:,0][-k:],
    #             res.get_prediction(df_temp).conf_int()[:,1][-k:], alpha = 0.3, color = 'gray')

    #sbplt.plot(df_temp['k'].values[-k:],res.get_prediction(df_temp).predicted_mean[-k:], color = 'black')

    sbplt.set_xlabel('k')
    


    #sbplt.set_xticks(range(0,31)[::5])
    #sbplt.set_xticklabels(range(0,31)[::5])
    sbplt.set_xlim([-32,32])
    #sbplt.set_xlabel('Bandwidth (± weeks around intervention)')
    sbplt.set_ylabel('Estimated log total volume')
    #sbplt.set_ylim([-1.5,2.5])

plt.tight_layout()

fig.suptitle('bread and flatbread, bandwidth K=30', position = (0.5,1.05), fontsize= 15)
# Out:
# Text(0.5, 1.05, 'bread and flatbread, bandwidth K=30')

# %%
import matplotlib.pyplot as mpl
mpl.rcParams['font.size'] = 12

fig, axes = plt.subplots(2,2, figsize = (10,10), sharey = True)


for model in ['Constant','Linear','Quadratic','Cubic']:
    
    point = []
    conf = []
        
    for k in range(3,31):
    
        df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                    #(df['country'] == 'IT') & \
                                    (df['k'] >= -k) & (df['k'] <= k)].copy()
        
        df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

        mod = smf.ols(generate_equation(model), 
                      data = df_temp)

        res = mod.fit(cov_type='hc0')
        
    
        if model == 'Cubic':
            point.append([res.params['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]'], res.params['intervention_flag:np.power(k, 3):year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]'], res.params['intervention_flag:np.power(k, 3):year[T.2020]']])
        elif model == "Quadratic":
            point.append([res.params['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]'], res.params['intervention_flag:np.power(k, 2):year[T.2020]']])
        elif model == "Linear":
            point.append([res.params['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]'], res.params['intervention_flag:k:year[T.2020]']])
        elif model == 'Constant':
            point.append([res.params['intervention_flag:year[T.2020]']])
            conf.append([res.bse['intervention_flag:year[T.2020]']])
            
    
    if model == 'Constant':
        sbplt = axes[0,0]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31),
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]), 
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
        
        idmax = np.argmax(np.array([i[0] for i in point]))
        sbplt.vlines(range(3,31)[idmax],-1.5,2.5, alpha = 0.5, color = 'tab:red', label = 'max α='+str(round(np.max(np.array([i[0] for i in point])),2)))
        
    elif model == 'Linear':
        sbplt = axes[0,1]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]),
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
        
        sbplt.plot(range(3,31), [i[1] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[1] for i in point]) - 2*np.array([i[1] for i in conf]),
                           np.array([i[1] for i in point]) + 2*np.array([i[1] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'β')
        
        idmax = np.argmax(np.array([i[0] for i in point]))
        sbplt.vlines(range(3,31)[idmax],-1.5,2.5, alpha = 0.5, color = 'tab:red', label = 'max α='+str(round(np.max(np.array([i[0] for i in point])),2)))
    
    elif model == 'Quadratic':
        sbplt = axes[1,0]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31),
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]), 
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
        
        sbplt.plot(range(3,31), [i[1] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[1] for i in point]) - 2*np.array([i[1] for i in conf]),
                           np.array([i[1] for i in point]) + 2*np.array([i[1] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'β')
    
        sbplt.plot(range(3,31), [i[2] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[2] for i in point]) - 2*np.array([i[2] for i in conf]),
                           np.array([i[2] for i in point]) + 2*np.array([i[2] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'γ')
    
    else:
        sbplt = axes[1,1]
        sbplt.plot(range(3,31), [i[0] for i in point], color = 'black')
        sbplt.fill_between(range(3,31),
                           np.array([i[0] for i in point]) - 2*np.array([i[0] for i in conf]), 
                           np.array([i[0] for i in point]) + 2*np.array([i[0] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'α')
       
        sbplt.plot(range(3,31), [i[1] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[1] for i in point]) - 2*np.array([i[1] for i in conf]),
                           np.array([i[1] for i in point]) + 2*np.array([i[1] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'β')
        
        sbplt.plot(range(3,31), [i[2] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[2] for i in point]) - 2*np.array([i[2] for i in conf]),
                           np.array([i[2] for i in point]) + 2*np.array([i[2] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'γ')
        
        sbplt.plot(range(3,31), [i[3] for i in point], color = 'black')
        sbplt.fill_between(range(3,31), 
                           np.array([i[3] for i in point]) - 2*np.array([i[3] for i in conf]),
                           np.array([i[3] for i in point]) + 2*np.array([i[3] for i in conf]), alpha = 0.3, edgecolor = 'black', label = 'δ')
    
    
    sbplt.set_title(model)
    sbplt.legend(loc = "upper right")
    sbplt.hlines(0,0,30, linestyle = '--')
    sbplt.set_xticks(range(0,31)[::5])
    sbplt.set_xticklabels(range(0,31)[::5])
    sbplt.set_xlim([-1,31])
    sbplt.set_xlabel('Bandwidth (± weeks around intervention)')
    sbplt.set_ylabel('Multiplicative effect')
    sbplt.set_ylim([-1.5,2.5])

plt.tight_layout()

fig.suptitle('Bread and flatbread', position = (0.5,1.05), fontsize= 15)
# Out:
# Text(0.5, 1.05, 'Bread and flatbread')

# %%
df_temp = df.loc[(df['category'] == 'bread and flatbread') & 
                                #(df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k)].copy()

df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

mod = smf.ols("volume_total ~ intervention_flag*k*C(country)", 
              data = df_temp)

res = mod.fit(cov_type='hc0')

res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           volume_total   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     663.5
# Date:                Sun, 14 Mar 2021   Prob (F-statistic):               0.00
# Time:                        16:01:09   Log-Likelihood:                -233.18
# No. Observations:                 998   AIC:                             562.4
# Df Residuals:                     950   BIC:                             797.8
# Df Model:                          47
# Covariance Type:                  hc0
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                4.7066      0.074     63.370      0.000       4.561       4.852
# C(country)[T.BR]                         2.1552      0.154     14.029      0.000       1.854       2.456
# C(country)[T.CA]                         0.1013      0.114      0.889      0.374      -0.122       0.325
# C(country)[T.DE]                        -0.2423      0.110     -2.209      0.027      -0.457      -0.027
# C(country)[T.ES]                         0.5755      0.169      3.403      0.001       0.244       0.907
# C(country)[T.FR]                         0.9511      0.165      5.770      0.000       0.628       1.274
# C(country)[T.GB]                         0.1739      0.172      1.010      0.313      -0.164       0.512
# C(country)[T.IN]                         1.1766      0.082     14.346      0.000       1.016       1.337
# C(country)[T.IT]                         0.6600      0.149      4.427      0.000       0.368       0.952
# C(country)[T.JP]                         0.7078      0.307      2.307      0.021       0.107       1.309
# C(country)[T.MX]                        -0.4710      0.114     -4.114      0.000      -0.695      -0.247
# C(country)[T.US]                         0.3078      0.104      2.956      0.003       0.104       0.512
# intervention_flag                        0.2901      0.118      2.451      0.014       0.058       0.522
# intervention_flag:C(country)[T.BR]       0.1110      0.196      0.566      0.571      -0.273       0.495
# intervention_flag:C(country)[T.CA]       0.0318      0.193      0.164      0.869      -0.347       0.410
# intervention_flag:C(country)[T.DE]      -0.1355      0.165     -0.820      0.412      -0.459       0.188
# intervention_flag:C(country)[T.ES]       0.2283      0.251      0.911      0.362      -0.263       0.719
# intervention_flag:C(country)[T.FR]       0.2255      0.244      0.924      0.356      -0.253       0.704
# intervention_flag:C(country)[T.GB]      -0.0937      0.240     -0.391      0.696      -0.563       0.376
# intervention_flag:C(country)[T.IN]       0.0695      0.162      0.429      0.668      -0.248       0.387
# intervention_flag:C(country)[T.IT]       0.3171      0.246      1.290      0.197      -0.165       0.799
# intervention_flag:C(country)[T.JP]       0.5217      0.322      1.620      0.105      -0.109       1.153
# intervention_flag:C(country)[T.MX]       0.0633      0.162      0.391      0.695      -0.254       0.380
# intervention_flag:C(country)[T.US]      -0.0933      0.166     -0.564      0.573      -0.418       0.231
# k                                        0.0180      0.010      1.830      0.067      -0.001       0.037
# k:C(country)[T.BR]                      -0.0124      0.020     -0.617      0.537      -0.052       0.027
# k:C(country)[T.CA]                      -0.0192      0.016     -1.211      0.226      -0.050       0.012
# k:C(country)[T.DE]                      -0.0134      0.015     -0.897      0.370      -0.043       0.016
# k:C(country)[T.ES]                      -0.0092      0.024     -0.387      0.698      -0.056       0.037
# k:C(country)[T.FR]                      -0.0055      0.023     -0.239      0.811      -0.051       0.040
# k:C(country)[T.GB]                       0.0123      0.022      0.552      0.581      -0.031       0.056
# k:C(country)[T.IN]                      -0.0063      0.011     -0.572      0.567      -0.028       0.015
# k:C(country)[T.IT]                      -0.0048      0.023     -0.211      0.833      -0.049       0.040
# k:C(country)[T.JP]                      -0.0367      0.033     -1.098      0.272      -0.102       0.029
# k:C(country)[T.MX]                      -0.0241      0.015     -1.629      0.103      -0.053       0.005
# k:C(country)[T.US]                      -0.0160      0.014     -1.115      0.265      -0.044       0.012
# intervention_flag:k                     -0.0302      0.011     -2.816      0.005      -0.051      -0.009
# intervention_flag:k:C(country)[T.BR]     0.0132      0.021      0.632      0.528      -0.028       0.054
# intervention_flag:k:C(country)[T.CA]     0.0177      0.017      1.016      0.310      -0.016       0.052
# intervention_flag:k:C(country)[T.DE]     0.0157      0.016      0.981      0.327      -0.016       0.047
# intervention_flag:k:C(country)[T.ES]    -0.0034      0.025     -0.136      0.892      -0.053       0.046
# intervention_flag:k:C(country)[T.FR]    -0.0062      0.025     -0.253      0.800      -0.054       0.042
# intervention_flag:k:C(country)[T.GB]    -0.0183      0.024     -0.775      0.438      -0.065       0.028
# intervention_flag:k:C(country)[T.IN]     0.0043      0.013      0.340      0.734      -0.021       0.029
# intervention_flag:k:C(country)[T.IT]    -0.0125      0.024     -0.512      0.609      -0.060       0.035
# intervention_flag:k:C(country)[T.JP]     0.0423      0.034      1.253      0.210      -0.024       0.109
# intervention_flag:k:C(country)[T.MX]     0.0340      0.016      2.164      0.030       0.003       0.065
# intervention_flag:k:C(country)[T.US]     0.0198      0.016      1.272      0.203      -0.011       0.050
# ==============================================================================
# Omnibus:                       68.688   Durbin-Watson:                   0.186
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              298.497
# Skew:                           0.087   Prob(JB):                     1.52e-65
# Kurtosis:                       5.674   Cond. No.                     1.47e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 1.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
def make_stars(val):
    if val<0.0001:
        return '****'
    elif val<0.001:
        return '***'
    elif val<0.01:
        return '**'
    elif val<0.05:
        return '*'
    else:
        return ''

# %%
import matplotlib.pyplot as mpl
mpl.rcParams['font.size'] = 12

fig, axes = plt.subplots(8,4, figsize = (10,15), sharex = True)

cats = ['dessert', 'soft drink', 'rice dish', 'soup', 'spice',
       'chicken dish', 'fish dish', 'fruit', 'cheese', 'pork dish',
       'vegetable', 'lamb dish', 'herb', 'confection', 'snack',
       'beef dish', 'liquor', 'pie', 'pasta and noodle dish',
       'bread and flatbread', 'chocolate bar', 'potato dish', 'stew',
       'egg dish', 'sauce', 'cocktail', 'salad', 'sandwich', 'cake',
       'sausage', 'pastry', 'pudding']

alphas = []
for cnt,c in enumerate(cats):
    
        
        k = 30
    
        df_temp = df.loc[(df['category'] == c) & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k)].copy()

        df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

        mod = smf.ols(generate_equation('Quadratic'), 
                  data = df_temp)

        res = mod.fit(cov_type='hc0')

        alphas.append(res.params['intervention_flag:year[T.2020]'])
        
        
effects, category_labels = zip(*sorted(zip(alphas, cats), reverse = True))
for cnt,c in enumerate(category_labels):
    
        df_temp = df.loc[(df['category'] == c) & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k)].copy()

        df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

        mod = smf.ols(generate_equation('Quadratic'), 
                  data = df_temp)

        res = mod.fit(cov_type='hc0')

        
        
        sbplt = axes[math.floor(cnt/4), cnt%4]
        
        sbplt.set_title(c+'\n α='+str(round(res.params['intervention_flag:year[T.2020]'],2))+(make_stars(res.pvalues['intervention_flag:year[T.2020]'])) +
                        ',\n β='+str(round(res.params['intervention_flag:k:year[T.2020]'],2)) + (make_stars(res.pvalues['intervention_flag:k:year[T.2020]'])) +
                       ',\n γ='+str(round(res.params['intervention_flag:np.power(k, 2):year[T.2020]'],2)) + (make_stars(res.pvalues['intervention_flag:np.power(k, 2):year[T.2020]'])))

        df_temp = df.loc[(df['category'] == c) & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k) & (df_temp['year'] == '2020')].copy()

        df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)
        
        sbplt.fill_between(df_temp['k'].values,res.get_prediction(df_temp).conf_int()[:,0],
                     res.get_prediction(df_temp).conf_int()[:,1], alpha = 0.3, color = 'gray')

        sbplt.plot(df_temp['k'].values,res.get_prediction(df_temp).predicted_mean, color = 'tab:blue', label = '2019')
        
        
        
        df_temp = df.loc[(df['category'] == c) & 
                                (df['country'] == 'IT') & \
                                (df['k'] >= -k) & (df['k'] <= k) & (df['year'] == '2019')].copy()

        df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)
        
        sbplt.fill_between(df_temp['k'].values,res.get_prediction(df_temp).conf_int()[:,0],
                     res.get_prediction(df_temp).conf_int()[:,1], alpha = 0.3, color = 'gray')

        sbplt.plot(df_temp['k'].values,res.get_prediction(df_temp).predicted_mean, color = 'tab:orange', label = '2019')
        
        #sbplt.legend()
        

        #sbplt.fill_between(df_temp['k'].values[k+1:2*k+1],res.get_prediction(df_temp).conf_int()[:,0][k+1:2*k+1],
        #             res.get_prediction(df_temp).conf_int()[:,1][k+1:2*k+1], alpha = 0.3, color = 'gray')

        #sbplt.plot(df_temp['k'].values[k+1:2*k+1],res.get_prediction(df_temp).predicted_mean[k+1:2*k+1], color = 'black')

        sbplt.set_xlim([-32,32])

        sbplt.set_xticks(range(-30,31)[::10])
        sbplt.set_xticklabels(range(-30,31)[::10])
plt.tight_layout()

fig.suptitle('bandwidth K=30, Italy', position = (0.5,1.05), fontsize= 15);

# %%
def generate_equation_interactions(order):
    if order == 'Cubic':
        eq = "volume_total ~ intervention_flag*k*year*C(country)*C(category) + intervention_flag*np.power(k,2)*year*C(country)*C(category) + intervention_flag*np.power(k,3)*year*C(country)*C(category)"
    elif order == "Quadratic":
        eq = "volume_total ~ intervention_flag*k*year*C(country)*C(category) + intervention_flag*np.power(k,2)*year*C(country)*C(category)"
    elif order == "Linear":
        eq = "volume_total ~ intervention_flag*k*year*C(country)*C(category)"
    elif order == 'Constant':
        eq = "volume_total ~ intervention_flag*year*C(country)*C(category)"
    return eq

# %%
df_temp = df.loc[(df['k'] >= -k) & (df['k'] <= k)].copy()

df_temp['volume_total'] = df_temp['volume_total'].apply(np.log1p)

mod = smf.ols(generate_equation_interactions('Quadratic'), data = df_temp)

result_interactions = mod.fit(cov_type='hc0')

# %%
result_interactions.summary()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4607, but rank is 4572
#   'rank is %d' % (J, J_), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           volume_total   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     4951.
# Date:                Sun, 14 Mar 2021   Prob (F-statistic):               0.00
# Time:                        16:02:37   Log-Likelihood:                 30701.
# No. Observations:               31936   AIC:                        -5.219e+04
# Df Residuals:                   27328   BIC:                        -1.361e+04
# Df Model:                        4607
# Covariance Type:                  hc0
# =======================================================================================================================================================================
#                                                                                                           coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                               5.3847      0.006    884.091      0.000       5.373       5.397
# year[T.2020]                                                                                           -0.0607      0.022     -2.706      0.007      -0.105      -0.017
# C(country)[T.BR]                                                                                        1.4234      0.024     60.248      0.000       1.377       1.470
# C(country)[T.CA]                                                                                        0.0534      0.020      2.671      0.008       0.014       0.093
# C(country)[T.DE]                                                                                       -0.5677      0.017    -32.699      0.000      -0.602      -0.534
# C(country)[T.ES]                                                                                        0.1306      0.033      3.907      0.000       0.065       0.196
# C(country)[T.FR]                                                                                        0.4960      0.011     45.539      0.000       0.475       0.517
# C(country)[T.GB]                                                                                       -0.1110      0.019     -5.781      0.000      -0.149      -0.073
# C(country)[T.IN]                                                                                       -0.0058      0.020     -0.296      0.767      -0.044       0.033
# C(country)[T.IT]                                                                                       -0.2040      0.029     -6.940      0.000      -0.262      -0.146
# C(country)[T.JP]                                                                                        1.2569      0.246      5.119      0.000       0.776       1.738
# C(country)[T.MX]                                                                                       -0.7418      0.042    -17.688      0.000      -0.824      -0.660
# C(country)[T.US]                                                                                        0.6282      0.031     20.495      0.000       0.568       0.688
# C(category)[T.bread and flatbread]                                                                     -0.8367      0.020    -41.471      0.000      -0.876      -0.797
# C(category)[T.cake]                                                                                    -0.5791      0.023    -24.974      0.000      -0.625      -0.534
# C(category)[T.cheese]                                                                                  -0.5313      0.027    -19.650      0.000      -0.584      -0.478
# C(category)[T.chicken dish]                                                                             0.0653      0.019      3.458      0.001       0.028       0.102
# C(category)[T.chocolate bar]                                                                           -2.9286      0.085    -34.312      0.000      -3.096      -2.761
# C(category)[T.cocktail]                                                                                -1.2324      0.014    -88.688      0.000      -1.260      -1.205
# C(category)[T.confection]                                                                               0.2500      0.015     16.305      0.000       0.220       0.280
# C(category)[T.dessert]                                                                                  0.4841      0.016     29.488      0.000       0.452       0.516
# C(category)[T.egg dish]                                                                                 0.0641      0.186      0.346      0.730      -0.299       0.428
# C(category)[T.fish dish]                                                                               -0.5584      0.029    -19.252      0.000      -0.615      -0.502
# C(category)[T.fruit]                                                                                    0.6012      0.009     65.042      0.000       0.583       0.619
# C(category)[T.herb]                                                                                    -0.8381      0.041    -20.667      0.000      -0.918      -0.759
# C(category)[T.lamb dish]                                                                               -1.5986      0.055    -29.027      0.000      -1.707      -1.491
# C(category)[T.liquor]                                                                                  -1.0704      0.015    -71.643      0.000      -1.100      -1.041
# C(category)[T.pasta and noodle dish]                                                                    0.3646      0.016     23.126      0.000       0.334       0.396
# C(category)[T.pastry]                                                                                  -1.5653      0.021    -73.879      0.000      -1.607      -1.524
# C(category)[T.pie]                                                                                     -1.1991      0.047    -25.562      0.000      -1.291      -1.107
# C(category)[T.pork dish]                                                                               -0.6376      0.020    -32.228      0.000      -0.676      -0.599
# C(category)[T.potato dish]                                                                             -1.7685      0.026    -69.038      0.000      -1.819      -1.718
# C(category)[T.pudding]                                                                                 -2.3951      0.023   -102.327      0.000      -2.441      -2.349
# C(category)[T.rice dish]                                                                               -0.3769      0.012    -31.707      0.000      -0.400      -0.354
# C(category)[T.salad]                                                                                   -0.9660      0.019    -50.044      0.000      -1.004      -0.928
# C(category)[T.sandwich]                                                                                -2.3935      0.016   -147.112      0.000      -2.425      -2.362
# C(category)[T.sauce]                                                                                   -0.1630      0.011    -15.052      0.000      -0.184      -0.142
# C(category)[T.sausage]                                                                                 -1.9897      0.065    -30.743      0.000      -2.117      -1.863
# C(category)[T.snack]                                                                                   -1.2806      0.022    -59.535      0.000      -1.323      -1.238
# C(category)[T.soft drink]                                                                              -1.0716      0.035    -31.051      0.000      -1.139      -1.004
# C(category)[T.soup]                                                                                    -0.5865      0.066     -8.886      0.000      -0.716      -0.457
# C(category)[T.spice]                                                                                   -0.0987      0.012     -7.973      0.000      -0.123      -0.074
# C(category)[T.stew]                                                                                    -2.4924      0.040    -62.051      0.000      -2.571      -2.414
# C(category)[T.vegetable]                                                                                0.3835      0.014     27.437      0.000       0.356       0.411
# year[T.2020]:C(country)[T.BR]                                                                           0.1621      0.082      1.988      0.047       0.002       0.322
# year[T.2020]:C(country)[T.CA]                                                                           0.0614      0.040      1.540      0.124      -0.017       0.139
# year[T.2020]:C(country)[T.DE]                                                                          -0.3174      0.033     -9.513      0.000      -0.383      -0.252
# year[T.2020]:C(country)[T.ES]                                                                          -0.0247      0.107     -0.230      0.818      -0.235       0.186
# year[T.2020]:C(country)[T.FR]                                                                          -0.0157      0.026     -0.602      0.547      -0.067       0.035
# year[T.2020]:C(country)[T.GB]                                                                           0.0234      0.077      0.305      0.760      -0.127       0.174
# year[T.2020]:C(country)[T.IN]                                                                          -0.0248      0.054     -0.458      0.647      -0.131       0.081
# year[T.2020]:C(country)[T.IT]                                                                          -0.2892      0.053     -5.426      0.000      -0.394      -0.185
# year[T.2020]:C(country)[T.JP]                                                                           0.0488      0.247      0.198      0.843      -0.436       0.533
# year[T.2020]:C(country)[T.MX]                                                                           0.0291      0.064      0.457      0.648      -0.096       0.154
# year[T.2020]:C(country)[T.US]                                                                           0.0275      0.081      0.340      0.734      -0.131       0.186
# year[T.2020]:C(category)[T.bread and flatbread]                                                         0.5219      0.063      8.235      0.000       0.398       0.646
# year[T.2020]:C(category)[T.cake]                                                                        0.0491      0.091      0.540      0.589      -0.129       0.227
# year[T.2020]:C(category)[T.cheese]                                                                     -0.0870      0.055     -1.592      0.111      -0.194       0.020
# year[T.2020]:C(category)[T.chicken dish]                                                                0.0620      0.040      1.561      0.119      -0.016       0.140
# year[T.2020]:C(category)[T.chocolate bar]                                                              -0.1308      0.130     -1.008      0.313      -0.385       0.124
# year[T.2020]:C(category)[T.cocktail]                                                                   -0.0769      0.039     -1.951      0.051      -0.154       0.000
# year[T.2020]:C(category)[T.confection]                                                                 -0.1689      0.062     -2.711      0.007      -0.291      -0.047
# year[T.2020]:C(category)[T.dessert]                                                                     0.1326      0.064      2.084      0.037       0.008       0.257
# year[T.2020]:C(category)[T.egg dish]                                                                   -0.0471      0.201     -0.235      0.814      -0.441       0.347
# year[T.2020]:C(category)[T.fish dish]                                                                  -0.0112      0.049     -0.230      0.818      -0.107       0.084
# year[T.2020]:C(category)[T.fruit]                                                                       0.0926      0.045      2.069      0.039       0.005       0.180
# year[T.2020]:C(category)[T.herb]                                                                        0.1824      0.053      3.437      0.001       0.078       0.286
# year[T.2020]:C(category)[T.lamb dish]                                                                   0.0923      0.075      1.223      0.221      -0.056       0.240
# year[T.2020]:C(category)[T.liquor]                                                                      0.1748      0.030      5.763      0.000       0.115       0.234
# year[T.2020]:C(category)[T.pasta and noodle dish]                                                       0.0838      0.028      3.024      0.002       0.029       0.138
# year[T.2020]:C(category)[T.pastry]                                                                      0.4054      0.061      6.674      0.000       0.286       0.524
# year[T.2020]:C(category)[T.pie]                                                                         0.1870      0.069      2.698      0.007       0.051       0.323
# year[T.2020]:C(category)[T.pork dish]                                                                   0.0690      0.032      2.159      0.031       0.006       0.132
# year[T.2020]:C(category)[T.potato dish]                                                                -0.0467      0.041     -1.135      0.256      -0.127       0.034
# year[T.2020]:C(category)[T.pudding]                                                                     0.0549      0.059      0.936      0.349      -0.060       0.170
# year[T.2020]:C(category)[T.rice dish]                                                                   0.0066      0.041      0.161      0.872      -0.073       0.087
# year[T.2020]:C(category)[T.salad]                                                                      -0.2411      0.043     -5.586      0.000      -0.326      -0.157
# year[T.2020]:C(category)[T.sandwich]                                                                   -0.1115      0.051     -2.177      0.029      -0.212      -0.011
# year[T.2020]:C(category)[T.sauce]                                                                       0.0529      0.054      0.989      0.323      -0.052       0.158
# year[T.2020]:C(category)[T.sausage]                                                                     0.0884      0.079      1.125      0.260      -0.066       0.242
# year[T.2020]:C(category)[T.snack]                                                                      -0.0715      0.056     -1.268      0.205      -0.182       0.039
# year[T.2020]:C(category)[T.soft drink]                                                                  0.0035      0.053      0.066      0.947      -0.101       0.108
# year[T.2020]:C(category)[T.soup]                                                                        0.2615      0.077      3.412      0.001       0.111       0.412
# year[T.2020]:C(category)[T.spice]                                                                       0.1230      0.037      3.326      0.001       0.051       0.196
# year[T.2020]:C(category)[T.stew]                                                                        0.2263      0.068      3.351      0.001       0.094       0.359
# year[T.2020]:C(category)[T.vegetable]                                                                   0.2677      0.044      6.112      0.000       0.182       0.354
# C(country)[T.BR]:C(category)[T.bread and flatbread]                                                     0.6866      0.045     15.395      0.000       0.599       0.774
# C(country)[T.CA]:C(category)[T.bread and flatbread]                                                     0.0758      0.035      2.184      0.029       0.008       0.144
# C(country)[T.DE]:C(category)[T.bread and flatbread]                                                     0.3308      0.040      8.331      0.000       0.253       0.409
# C(country)[T.ES]:C(category)[T.bread and flatbread]                                                     0.3873      0.046      8.395      0.000       0.297       0.478
# C(country)[T.FR]:C(category)[T.bread and flatbread]                                                     0.3906      0.028     13.712      0.000       0.335       0.446
# C(country)[T.GB]:C(category)[T.bread and flatbread]                                                     0.1386      0.032      4.364      0.000       0.076       0.201
# C(country)[T.IN]:C(category)[T.bread and flatbread]                                                     1.3445      0.054     24.785      0.000       1.238       1.451
# C(country)[T.IT]:C(category)[T.bread and flatbread]                                                     0.8245      0.052     15.976      0.000       0.723       0.926
# C(country)[T.JP]:C(category)[T.bread and flatbread]                                                     0.1836      0.395      0.464      0.642      -0.591       0.958
# C(country)[T.MX]:C(category)[T.bread and flatbread]                                                     0.3031      0.065      4.682      0.000       0.176       0.430
# C(country)[T.US]:C(category)[T.bread and flatbread]                                                    -0.2230      0.038     -5.903      0.000      -0.297      -0.149
# C(country)[T.BR]:C(category)[T.cake]                                                                    0.7491      0.038     19.902      0.000       0.675       0.823
# C(country)[T.CA]:C(category)[T.cake]                                                                   -0.1675      0.039     -4.313      0.000      -0.244      -0.091
# C(country)[T.DE]:C(category)[T.cake]                                                                    0.2231      0.037      6.078      0.000       0.151       0.295
# C(country)[T.ES]:C(category)[T.cake]                                                                    0.6178      0.088      7.030      0.000       0.446       0.790
# C(country)[T.FR]:C(category)[T.cake]                                                                    0.1111      0.054      2.052      0.040       0.005       0.217
# C(country)[T.GB]:C(category)[T.cake]                                                                    0.3597      0.149      2.412      0.016       0.067       0.652
# C(country)[T.IN]:C(category)[T.cake]                                                                    0.8487      0.036     23.738      0.000       0.779       0.919
# C(country)[T.IT]:C(category)[T.cake]                                                                    0.8593      0.064     13.398      0.000       0.734       0.985
# C(country)[T.JP]:C(category)[T.cake]                                                                   -0.7895      0.285     -2.767      0.006      -1.349      -0.230
# C(country)[T.MX]:C(category)[T.cake]                                                                   -0.1568      0.071     -2.218      0.027      -0.295      -0.018
# C(country)[T.US]:C(category)[T.cake]                                                                   -0.6847      0.053    -12.898      0.000      -0.789      -0.581
# C(country)[T.BR]:C(category)[T.cheese]                                                                  0.5137      0.043     11.876      0.000       0.429       0.598
# C(country)[T.CA]:C(category)[T.cheese]                                                                  0.0506      0.034      1.506      0.132      -0.015       0.117
# C(country)[T.DE]:C(category)[T.cheese]                                                                  0.3360      0.034      9.880      0.000       0.269       0.403
# C(country)[T.ES]:C(category)[T.cheese]                                                                  0.5702      0.048     11.986      0.000       0.477       0.663
# C(country)[T.FR]:C(category)[T.cheese]                                                                  0.8126      0.029     27.670      0.000       0.755       0.870
# C(country)[T.GB]:C(category)[T.cheese]                                                                  0.2632      0.042      6.334      0.000       0.182       0.345
# C(country)[T.IN]:C(category)[T.cheese]                                                                  1.4972      0.070     21.305      0.000       1.359       1.635
# C(country)[T.IT]:C(category)[T.cheese]                                                                  1.1784      0.045     26.079      0.000       1.090       1.267
# C(country)[T.JP]:C(category)[T.cheese]                                                                 -0.6481      0.300     -2.164      0.030      -1.235      -0.061
# C(country)[T.MX]:C(category)[T.cheese]                                                                  0.2781      0.064      4.318      0.000       0.152       0.404
# C(country)[T.US]:C(category)[T.cheese]                                                                 -0.2959      0.042     -7.052      0.000      -0.378      -0.214
# C(country)[T.BR]:C(category)[T.chicken dish]                                                            0.3031      0.046      6.564      0.000       0.213       0.394
# C(country)[T.CA]:C(category)[T.chicken dish]                                                           -0.0426      0.030     -1.438      0.150      -0.101       0.015
# C(country)[T.DE]:C(category)[T.chicken dish]                                                           -1.0495      0.044    -23.852      0.000      -1.136      -0.963
# C(country)[T.ES]:C(category)[T.chicken dish]                                                           -0.0992      0.048     -2.087      0.037      -0.192      -0.006
# C(country)[T.FR]:C(category)[T.chicken dish]                                                            0.0089      0.023      0.386      0.699      -0.036       0.054
# C(country)[T.GB]:C(category)[T.chicken dish]                                                            0.0612      0.029      2.083      0.037       0.004       0.119
# C(country)[T.IN]:C(category)[T.chicken dish]                                                            0.8192      0.039     21.226      0.000       0.744       0.895
# C(country)[T.IT]:C(category)[T.chicken dish]                                                           -0.0707      0.049     -1.435      0.151      -0.167       0.026
# C(country)[T.JP]:C(category)[T.chicken dish]                                                           -0.4907      0.259     -1.896      0.058      -0.998       0.016
# C(country)[T.MX]:C(category)[T.chicken dish]                                                           -0.0832      0.048     -1.728      0.084      -0.178       0.011
# C(country)[T.US]:C(category)[T.chicken dish]                                                           -0.3743      0.037    -10.143      0.000      -0.447      -0.302
# C(country)[T.BR]:C(category)[T.chocolate bar]                                                           0.7102      0.110      6.455      0.000       0.495       0.926
# C(country)[T.CA]:C(category)[T.chocolate bar]                                                          -0.8405      0.122     -6.878      0.000      -1.080      -0.601
# C(country)[T.DE]:C(category)[T.chocolate bar]                                                           0.5759      0.089      6.500      0.000       0.402       0.750
# C(country)[T.ES]:C(category)[T.chocolate bar]                                                           0.3615      0.132      2.735      0.006       0.102       0.621
# C(country)[T.FR]:C(category)[T.chocolate bar]                                                           0.3046      0.097      3.125      0.002       0.114       0.496
# C(country)[T.GB]:C(category)[T.chocolate bar]                                                           0.4975      0.108      4.617      0.000       0.286       0.709
# C(country)[T.IN]:C(category)[T.chocolate bar]                                                           1.2057      0.129      9.334      0.000       0.953       1.459
# C(country)[T.IT]:C(category)[T.chocolate bar]                                                           1.4325      0.123     11.614      0.000       1.191       1.674
# C(country)[T.JP]:C(category)[T.chocolate bar]                                                          -1.3411      0.285     -4.714      0.000      -1.899      -0.783
# C(country)[T.MX]:C(category)[T.chocolate bar]                                                          -0.5947      0.152     -3.918      0.000      -0.892      -0.297
# C(country)[T.US]:C(category)[T.chocolate bar]                                                          -0.8843      0.102     -8.641      0.000      -1.085      -0.684
# C(country)[T.BR]:C(category)[T.cocktail]                                                               -0.0339      0.088     -0.387      0.699      -0.206       0.138
# C(country)[T.CA]:C(category)[T.cocktail]                                                               -0.2220      0.028     -7.945      0.000      -0.277      -0.167
# C(country)[T.DE]:C(category)[T.cocktail]                                                                0.2225      0.039      5.672      0.000       0.146       0.299
# C(country)[T.ES]:C(category)[T.cocktail]                                                                0.4093      0.050      8.121      0.000       0.311       0.508
# C(country)[T.FR]:C(category)[T.cocktail]                                                                0.3324      0.039      8.499      0.000       0.256       0.409
# C(country)[T.GB]:C(category)[T.cocktail]                                                                0.1999      0.032      6.192      0.000       0.137       0.263
# C(country)[T.IN]:C(category)[T.cocktail]                                                                0.7834      0.068     11.529      0.000       0.650       0.917
# C(country)[T.IT]:C(category)[T.cocktail]                                                                1.3464      0.222      6.078      0.000       0.912       1.781
# C(country)[T.JP]:C(category)[T.cocktail]                                                               -0.7918      0.247     -3.202      0.001      -1.277      -0.307
# C(country)[T.MX]:C(category)[T.cocktail]                                                               -0.0317      0.091     -0.349      0.727      -0.210       0.146
# C(country)[T.US]:C(category)[T.cocktail]                                                               -0.1307      0.038     -3.444      0.001      -0.205      -0.056
# C(country)[T.BR]:C(category)[T.confection]                                                              1.6742      0.030     56.476      0.000       1.616       1.732
# C(country)[T.CA]:C(category)[T.confection]                                                             -0.4098      0.037    -10.947      0.000      -0.483      -0.336
# C(country)[T.DE]:C(category)[T.confection]                                                              0.1520      0.047      3.234      0.001       0.060       0.244
# C(country)[T.ES]:C(category)[T.confection]                                                              0.1643      0.063      2.612      0.009       0.041       0.288
# C(country)[T.FR]:C(category)[T.confection]                                                              0.8051      0.036     22.560      0.000       0.735       0.875
# C(country)[T.GB]:C(category)[T.confection]                                                              0.2264      0.041      5.583      0.000       0.147       0.306
# C(country)[T.IN]:C(category)[T.confection]                                                              1.5656      0.096     16.237      0.000       1.377       1.755
# C(country)[T.IT]:C(category)[T.confection]                                                              0.2274      0.072      3.145      0.002       0.086       0.369
# C(country)[T.JP]:C(category)[T.confection]                                                             -1.0023      0.390     -2.567      0.010      -1.768      -0.237
# C(country)[T.MX]:C(category)[T.confection]                                                              0.4369      0.063      6.941      0.000       0.314       0.560
# C(country)[T.US]:C(category)[T.confection]                                                             -0.8015      0.046    -17.270      0.000      -0.892      -0.711
# C(country)[T.BR]:C(category)[T.dessert]                                                                 0.7034      0.032     22.297      0.000       0.642       0.765
# C(country)[T.CA]:C(category)[T.dessert]                                                                 0.0039      0.030      0.128      0.898      -0.055       0.063
# C(country)[T.DE]:C(category)[T.dessert]                                                                 0.0836      0.026      3.216      0.001       0.033       0.135
# C(country)[T.ES]:C(category)[T.dessert]                                                                 0.3656      0.048      7.673      0.000       0.272       0.459
# C(country)[T.FR]:C(category)[T.dessert]                                                                 0.4862      0.083      5.869      0.000       0.324       0.649
# C(country)[T.GB]:C(category)[T.dessert]                                                                 0.0753      0.031      2.400      0.016       0.014       0.137
# C(country)[T.IN]:C(category)[T.dessert]                                                                 1.5335      0.041     37.625      0.000       1.454       1.613
# C(country)[T.IT]:C(category)[T.dessert]                                                                 0.7239      0.048     15.194      0.000       0.630       0.817
# C(country)[T.JP]:C(category)[T.dessert]                                                                -0.8066      0.277     -2.915      0.004      -1.349      -0.264
# C(country)[T.MX]:C(category)[T.dessert]                                                                 0.0342      0.057      0.597      0.550      -0.078       0.146
# C(country)[T.US]:C(category)[T.dessert]                                                                -0.3103      0.036     -8.569      0.000      -0.381      -0.239
# C(country)[T.BR]:C(category)[T.egg dish]                                                                0.0313      0.188      0.166      0.868      -0.338       0.401
# C(country)[T.CA]:C(category)[T.egg dish]                                                               -0.7045      0.189     -3.734      0.000      -1.074      -0.335
# C(country)[T.DE]:C(category)[T.egg dish]                                                               -0.8918      0.188     -4.731      0.000      -1.261      -0.522
# C(country)[T.ES]:C(category)[T.egg dish]                                                               -0.0201      0.190     -0.106      0.916      -0.392       0.352
# C(country)[T.FR]:C(category)[T.egg dish]                                                                0.1433      0.187      0.766      0.444      -0.223       0.510
# C(country)[T.GB]:C(category)[T.egg dish]                                                               -0.0413      0.187     -0.221      0.825      -0.407       0.325
# C(country)[T.IN]:C(category)[T.egg dish]                                                                0.4393      0.188      2.335      0.020       0.071       0.808
# C(country)[T.IT]:C(category)[T.egg dish]                                                                0.2121      0.202      1.052      0.293      -0.183       0.607
# C(country)[T.JP]:C(category)[T.egg dish]                                                               -1.4820      0.311     -4.762      0.000      -2.092      -0.872
# C(country)[T.MX]:C(category)[T.egg dish]                                                               -0.0638      0.191     -0.333      0.739      -0.439       0.311
# C(country)[T.US]:C(category)[T.egg dish]                                                               -0.9349      0.189     -4.959      0.000      -1.304      -0.565
# C(country)[T.BR]:C(category)[T.fish dish]                                                               0.0510      0.046      1.109      0.267      -0.039       0.141
# C(country)[T.CA]:C(category)[T.fish dish]                                                              -0.2540      0.039     -6.496      0.000      -0.331      -0.177
# C(country)[T.DE]:C(category)[T.fish dish]                                                              -0.3004      0.056     -5.370      0.000      -0.410      -0.191
# C(country)[T.ES]:C(category)[T.fish dish]                                                               0.4383      0.064      6.842      0.000       0.313       0.564
# C(country)[T.FR]:C(category)[T.fish dish]                                                               0.5339      0.036     14.831      0.000       0.463       0.604
# C(country)[T.GB]:C(category)[T.fish dish]                                                               0.0081      0.042      0.190      0.849      -0.075       0.091
# C(country)[T.IN]:C(category)[T.fish dish]                                                               0.0395      0.057      0.694      0.488      -0.072       0.151
# C(country)[T.IT]:C(category)[T.fish dish]                                                               0.4873      0.055      8.834      0.000       0.379       0.595
# C(country)[T.JP]:C(category)[T.fish dish]                                                              -0.2952      0.251     -1.177      0.239      -0.787       0.196
# C(country)[T.MX]:C(category)[T.fish dish]                                                              -0.7456      0.066    -11.345      0.000      -0.874      -0.617
# C(country)[T.US]:C(category)[T.fish dish]                                                              -0.4687      0.047    -10.032      0.000      -0.560      -0.377
# C(country)[T.BR]:C(category)[T.fruit]                                                                   0.5883      0.027     21.880      0.000       0.536       0.641
# C(country)[T.CA]:C(category)[T.fruit]                                                                  -0.1661      0.024     -6.928      0.000      -0.213      -0.119
# C(country)[T.DE]:C(category)[T.fruit]                                                                   0.0735      0.039      1.876      0.061      -0.003       0.150
# C(country)[T.ES]:C(category)[T.fruit]                                                                   0.4757      0.041     11.467      0.000       0.394       0.557
# C(country)[T.FR]:C(category)[T.fruit]                                                                   0.0788      0.019      4.089      0.000       0.041       0.117
# C(country)[T.GB]:C(category)[T.fruit]                                                                   0.0006      0.029      0.020      0.984      -0.055       0.056
# C(country)[T.IN]:C(category)[T.fruit]                                                                   1.7878      0.028     62.829      0.000       1.732       1.844
# C(country)[T.IT]:C(category)[T.fruit]                                                                   0.6360      0.040     15.823      0.000       0.557       0.715
# C(country)[T.JP]:C(category)[T.fruit]                                                                  -0.5180      0.261     -1.986      0.047      -1.029      -0.007
# C(country)[T.MX]:C(category)[T.fruit]                                                                   0.7323      0.045     16.301      0.000       0.644       0.820
# C(country)[T.US]:C(category)[T.fruit]                                                                  -0.3382      0.032    -10.645      0.000      -0.400      -0.276
# C(country)[T.BR]:C(category)[T.herb]                                                                    0.2700      0.048      5.595      0.000       0.175       0.365
# C(country)[T.CA]:C(category)[T.herb]                                                                   -0.2231      0.046     -4.838      0.000      -0.313      -0.133
# C(country)[T.DE]:C(category)[T.herb]                                                                    0.2661      0.070      3.794      0.000       0.129       0.404
# C(country)[T.ES]:C(category)[T.herb]                                                                    0.2551      0.054      4.730      0.000       0.149       0.361
# C(country)[T.FR]:C(category)[T.herb]                                                                    0.1717      0.059      2.923      0.003       0.057       0.287
# C(country)[T.GB]:C(category)[T.herb]                                                                   -0.0138      0.049     -0.280      0.779      -0.110       0.083
# C(country)[T.IN]:C(category)[T.herb]                                                                    1.6645      0.049     34.052      0.000       1.569       1.760
# C(country)[T.IT]:C(category)[T.herb]                                                                    0.9781      0.058     16.954      0.000       0.865       1.091
# C(country)[T.JP]:C(category)[T.herb]                                                                   -0.8885      0.252     -3.520      0.000      -1.383      -0.394
# C(country)[T.MX]:C(category)[T.herb]                                                                   -1.0101      0.069    -14.653      0.000      -1.145      -0.875
# C(country)[T.US]:C(category)[T.herb]                                                                   -0.4985      0.052     -9.588      0.000      -0.600      -0.397
# C(country)[T.BR]:C(category)[T.lamb dish]                                                              -0.2006      0.073     -2.754      0.006      -0.343      -0.058
# C(country)[T.CA]:C(category)[T.lamb dish]                                                              -0.9218      0.062    -14.835      0.000      -1.044      -0.800
# C(country)[T.DE]:C(category)[T.lamb dish]                                                               0.3560      0.064      5.521      0.000       0.230       0.482
# C(country)[T.ES]:C(category)[T.lamb dish]                                                              -1.3442      0.171     -7.880      0.000      -1.679      -1.010
# C(country)[T.FR]:C(category)[T.lamb dish]                                                              -1.5586      0.119    -13.148      0.000      -1.791      -1.326
# C(country)[T.GB]:C(category)[T.lamb dish]                                                               0.0914      0.070      1.296      0.195      -0.047       0.229
# C(country)[T.IN]:C(category)[T.lamb dish]                                                               1.1127      0.074     15.112      0.000       0.968       1.257
# C(country)[T.IT]:C(category)[T.lamb dish]                                                              -0.3996      0.094     -4.248      0.000      -0.584      -0.215
# C(country)[T.JP]:C(category)[T.lamb dish]                                                              -1.9418      0.330     -5.888      0.000      -2.588      -1.295
# C(country)[T.MX]:C(category)[T.lamb dish]                                                              -2.6909      0.094    -28.700      0.000      -2.875      -2.507
# C(country)[T.US]:C(category)[T.lamb dish]                                                              -1.6071      0.065    -24.829      0.000      -1.734      -1.480
# C(country)[T.BR]:C(category)[T.liquor]                                                                  0.5193      0.041     12.814      0.000       0.440       0.599
# C(country)[T.CA]:C(category)[T.liquor]                                                                 -0.1802      0.028     -6.471      0.000      -0.235      -0.126
# C(country)[T.DE]:C(category)[T.liquor]                                                                  0.5085      0.024     20.767      0.000       0.461       0.556
# C(country)[T.ES]:C(category)[T.liquor]                                                                  0.3750      0.052      7.262      0.000       0.274       0.476
# C(country)[T.FR]:C(category)[T.liquor]                                                                  0.3755      0.048      7.775      0.000       0.281       0.470
# C(country)[T.GB]:C(category)[T.liquor]                                                                  0.5495      0.054     10.202      0.000       0.444       0.655
# C(country)[T.IN]:C(category)[T.liquor]                                                                  1.3560      0.057     23.781      0.000       1.244       1.468
# C(country)[T.IT]:C(category)[T.liquor]                                                                  0.9410      0.050     18.966      0.000       0.844       1.038
# C(country)[T.JP]:C(category)[T.liquor]                                                                 -0.3721      0.266     -1.398      0.162      -0.894       0.150
# C(country)[T.MX]:C(category)[T.liquor]                                                                  0.8998      0.054     16.656      0.000       0.794       1.006
# C(country)[T.US]:C(category)[T.liquor]                                                                 -0.1972      0.037     -5.384      0.000      -0.269      -0.125
# C(country)[T.BR]:C(category)[T.pasta and noodle dish]                                                   0.7247      0.040     18.084      0.000       0.646       0.803
# C(country)[T.CA]:C(category)[T.pasta and noodle dish]                                                  -0.0847      0.029     -2.946      0.003      -0.141      -0.028
# C(country)[T.DE]:C(category)[T.pasta and noodle dish]                                                   0.4987      0.024     20.780      0.000       0.452       0.546
# C(country)[T.ES]:C(category)[T.pasta and noodle dish]                                                   0.3847      0.052      7.377      0.000       0.282       0.487
# C(country)[T.FR]:C(category)[T.pasta and noodle dish]                                                   0.3797      0.022     17.301      0.000       0.337       0.423
# C(country)[T.GB]:C(category)[T.pasta and noodle dish]                                                  -0.1359      0.026     -5.276      0.000      -0.186      -0.085
# C(country)[T.IN]:C(category)[T.pasta and noodle dish]                                                   0.5861      0.045     12.888      0.000       0.497       0.675
# C(country)[T.IT]:C(category)[T.pasta and noodle dish]                                                   1.5018      0.036     41.824      0.000       1.431       1.572
# C(country)[T.JP]:C(category)[T.pasta and noodle dish]                                                  -0.1665      0.297     -0.560      0.576      -0.749       0.416
# C(country)[T.MX]:C(category)[T.pasta and noodle dish]                                                   0.2996      0.049      6.116      0.000       0.204       0.396
# C(country)[T.US]:C(category)[T.pasta and noodle dish]                                                  -0.3519      0.035     -9.935      0.000      -0.421      -0.282
# C(country)[T.BR]:C(category)[T.pastry]                                                                 -0.2469      0.050     -4.933      0.000      -0.345      -0.149
# C(country)[T.CA]:C(category)[T.pastry]                                                                 -0.1425      0.044     -3.260      0.001      -0.228      -0.057
# C(country)[T.DE]:C(category)[T.pastry]                                                                  0.3952      0.047      8.424      0.000       0.303       0.487
# C(country)[T.ES]:C(category)[T.pastry]                                                                  0.7314      0.081      9.012      0.000       0.572       0.891
# C(country)[T.FR]:C(category)[T.pastry]                                                                  1.4035      0.050     28.161      0.000       1.306       1.501
# C(country)[T.GB]:C(category)[T.pastry]                                                                  0.2352      0.035      6.658      0.000       0.166       0.304
# C(country)[T.IN]:C(category)[T.pastry]                                                                  2.2005      0.049     44.710      0.000       2.104       2.297
# C(country)[T.IT]:C(category)[T.pastry]                                                                  1.5183      0.089     17.107      0.000       1.344       1.692
# C(country)[T.JP]:C(category)[T.pastry]                                                                 -1.6652      0.249     -6.681      0.000      -2.154      -1.177
# C(country)[T.MX]:C(category)[T.pastry]                                                                  0.9376      0.055     16.979      0.000       0.829       1.046
# C(country)[T.US]:C(category)[T.pastry]                                                                 -0.6258      0.063     -9.968      0.000      -0.749      -0.503
# C(country)[T.BR]:C(category)[T.pie]                                                                     0.5101      0.089      5.741      0.000       0.336       0.684
# C(country)[T.CA]:C(category)[T.pie]                                                                    -0.3475      0.097     -3.598      0.000      -0.537      -0.158
# C(country)[T.DE]:C(category)[T.pie]                                                                    -0.2038      0.061     -3.315      0.001      -0.324      -0.083
# C(country)[T.ES]:C(category)[T.pie]                                                                     0.9925      0.077     12.889      0.000       0.842       1.143
# C(country)[T.FR]:C(category)[T.pie]                                                                     0.9507      0.062     15.348      0.000       0.829       1.072
# C(country)[T.GB]:C(category)[T.pie]                                                                     0.2361      0.052      4.498      0.000       0.133       0.339
# C(country)[T.IN]:C(category)[T.pie]                                                                     0.3507      0.053      6.656      0.000       0.247       0.454
# C(country)[T.IT]:C(category)[T.pie]                                                                     0.8621      0.108      8.011      0.000       0.651       1.073
# C(country)[T.JP]:C(category)[T.pie]                                                                    -1.1695      0.267     -4.388      0.000      -1.692      -0.647
# C(country)[T.MX]:C(category)[T.pie]                                                                    -1.7505      0.112    -15.564      0.000      -1.971      -1.530
# C(country)[T.US]:C(category)[T.pie]                                                                    -0.5510      0.195     -2.832      0.005      -0.932      -0.170
# C(country)[T.BR]:C(category)[T.pork dish]                                                               0.0876      0.036      2.409      0.016       0.016       0.159
# C(country)[T.CA]:C(category)[T.pork dish]                                                               0.1980      0.035      5.740      0.000       0.130       0.266
# ...
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.sandwich]                 -0.0176      0.007     -2.364      0.018      -0.032      -0.003
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.sandwich]                  0.0020      0.004      0.522      0.602      -0.005       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.sandwich]                  0.0053      0.005      1.092      0.275      -0.004       0.015
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.sauce]                     0.0018      0.004      0.516      0.606      -0.005       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.sauce]                     0.0011      0.002      0.467      0.640      -0.003       0.006
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.sauce]                    -0.0040      0.003     -1.330      0.184      -0.010       0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.sauce]                     0.0003      0.005      0.053      0.958      -0.010       0.011
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.sauce]                    -0.0039      0.002     -1.799      0.072      -0.008       0.000
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.sauce]                     0.0019      0.003      0.575      0.565      -0.005       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.sauce]                    -0.0057      0.003     -1.986      0.047      -0.011   -7.59e-05
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.sauce]                    -0.0002      0.004     -0.041      0.968      -0.008       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.sauce]                    -0.0489      0.006     -7.697      0.000      -0.061      -0.036
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.sauce]                     0.0023      0.003      0.740      0.459      -0.004       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.sauce]                     0.0011      0.004      0.280      0.779      -0.007       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.sausage]                  -0.0021      0.005     -0.381      0.703      -0.013       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.sausage]                   0.0048      0.003      1.389      0.165      -0.002       0.012
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.sausage]                   0.0118      0.009      1.336      0.182      -0.006       0.029
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.sausage]                   0.0089      0.007      1.242      0.214      -0.005       0.023
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.sausage]                   0.0014      0.003      0.420      0.675      -0.005       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.sausage]                   0.0003      0.004      0.075      0.940      -0.008       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.sausage]                   0.0031      0.007      0.467      0.641      -0.010       0.016
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.sausage]                   0.0065      0.005      1.221      0.222      -0.004       0.017
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.sausage]                  -0.0486      0.007     -7.084      0.000      -0.062      -0.035
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.sausage]                   0.0051      0.004      1.218      0.223      -0.003       0.013
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.sausage]                   0.0019      0.004      0.446      0.655      -0.007       0.010
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.snack]                    -0.0013      0.004     -0.311      0.755      -0.009       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.snack]                     0.0011      0.004      0.314      0.753      -0.006       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.snack]                    -0.0028      0.003     -0.794      0.427      -0.010       0.004
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.snack]                     0.0040      0.004      0.994      0.320      -0.004       0.012
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.snack]                    -0.0063      0.003     -1.931      0.053      -0.013    9.43e-05
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.snack]                     0.0018      0.004      0.473      0.636      -0.006       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.snack]                    -0.0083      0.003     -2.850      0.004      -0.014      -0.003
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.snack]                  2.113e-05      0.006      0.004      0.997      -0.011       0.011
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.snack]                    -0.0452      0.007     -6.895      0.000      -0.058      -0.032
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.snack]                    -0.0005      0.004     -0.129      0.897      -0.007       0.006
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.snack]                     0.0057      0.004      1.369      0.171      -0.002       0.014
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.soft drink]                0.0032      0.004      0.904      0.366      -0.004       0.010
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.soft drink]                0.0013      0.004      0.359      0.720      -0.006       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.soft drink]               -0.0001      0.003     -0.033      0.974      -0.007       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.soft drink]                0.0167      0.005      3.681      0.000       0.008       0.026
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.soft drink]                0.0032      0.003      0.950      0.342      -0.003       0.010
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.soft drink]                0.0005      0.004      0.127      0.899      -0.007       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.soft drink]                0.0016      0.004      0.414      0.679      -0.006       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.soft drink]                0.0091      0.005      1.927      0.054      -0.000       0.018
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.soft drink]               -0.0425      0.007     -6.425      0.000      -0.055      -0.030
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.soft drink]               -0.0003      0.003     -0.083      0.934      -0.007       0.006
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.soft drink]                0.0039      0.004      0.995      0.320      -0.004       0.011
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.soup]                      0.0057      0.005      1.098      0.272      -0.004       0.016
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.soup]                     -0.0043      0.003     -1.437      0.151      -0.010       0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.soup]                     -0.0049      0.004     -1.286      0.199      -0.012       0.003
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.soup]                      0.0052      0.005      0.973      0.330      -0.005       0.016
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.soup]                     -0.0056      0.003     -1.920      0.055      -0.011       0.000
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.soup]                     -0.0035      0.004     -0.982      0.326      -0.010       0.003
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.soup]                     -0.0053      0.004     -1.513      0.130      -0.012       0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.soup]                      0.0036      0.004      0.999      0.318      -0.004       0.011
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.soup]                     -0.0135      0.008     -1.701      0.089      -0.029       0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.soup]                     -0.0011      0.004     -0.266      0.790      -0.010       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.soup]                     -0.0047      0.004     -1.143      0.253      -0.013       0.003
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.spice]                     0.0014      0.003      0.463      0.644      -0.004       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.spice]                    -0.0019      0.003     -0.725      0.468      -0.007       0.003
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.spice]                    -0.0065      0.003     -1.930      0.054      -0.013       0.000
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.spice]                     0.0064      0.004      1.436      0.151      -0.002       0.015
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.spice]                     0.0069      0.005      1.380      0.168      -0.003       0.017
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.spice]                     0.0007      0.003      0.245      0.806      -0.005       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.spice]                    -0.0039      0.003     -1.489      0.137      -0.009       0.001
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.spice]                     0.0072      0.003      2.362      0.018       0.001       0.013
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.spice]                    -0.0417      0.006     -6.570      0.000      -0.054      -0.029
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.spice]                     0.0037      0.003      1.380      0.167      -0.002       0.009
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.spice]                     0.0006      0.003      0.191      0.849      -0.006       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.stew]                     -0.0092      0.006     -1.603      0.109      -0.020       0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.stew]                     -0.0059      0.006     -1.033      0.301      -0.017       0.005
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.stew]                     -0.0024      0.005     -0.465      0.642      -0.012       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.stew]                     -0.0045      0.007     -0.606      0.544      -0.019       0.010
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.stew]                     -0.0011      0.005     -0.222      0.825      -0.011       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.stew]                     -0.0021      0.005     -0.420      0.674      -0.012       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.stew]                     -0.0116      0.005     -2.364      0.018      -0.021      -0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.stew]                      0.0207      0.009      2.263      0.024       0.003       0.039
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.stew]                     -0.0509      0.008     -6.637      0.000      -0.066      -0.036
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.stew]                      0.0043      0.005      0.851      0.395      -0.006       0.014
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.stew]                     -0.0028      0.006     -0.488      0.626      -0.014       0.008
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.BR]:C(category)[T.vegetable]                -0.0005      0.004     -0.150      0.881      -0.008       0.007
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.CA]:C(category)[T.vegetable]                 0.0011      0.002      0.494      0.622      -0.003       0.006
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.DE]:C(category)[T.vegetable]                -0.0057      0.003     -2.023      0.043      -0.011      -0.000
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.ES]:C(category)[T.vegetable]                 0.0020      0.004      0.471      0.637      -0.006       0.010
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.FR]:C(category)[T.vegetable]                 0.0007      0.003      0.256      0.798      -0.005       0.006
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.GB]:C(category)[T.vegetable]                -0.0046      0.004     -1.280      0.201      -0.012       0.002
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IN]:C(category)[T.vegetable]                -0.0068      0.003     -2.009      0.045      -0.014      -0.000
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.IT]:C(category)[T.vegetable]                 0.0050      0.003      1.539      0.124      -0.001       0.011
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.JP]:C(category)[T.vegetable]                -0.0414      0.006     -6.524      0.000      -0.054      -0.029
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.MX]:C(category)[T.vegetable]                 0.0063      0.003      2.050      0.040       0.000       0.012
# intervention_flag:np.power(k, 2):year[T.2020]:C(country)[T.US]:C(category)[T.vegetable]                 0.0012      0.004      0.351      0.726      -0.006       0.008
# ==============================================================================
# Omnibus:                    10002.152   Durbin-Watson:                   1.562
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           278436.890
# Skew:                           0.915   Prob(JB):                         0.00
# Kurtosis:                      17.349   Cond. No.                     4.29e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 4.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sorted(cats)
# Out:
# ['beef dish',
#  'bread and flatbread',
#  'cake',
#  'cheese',
#  'chicken dish',
#  'chocolate bar',
#  'cocktail',
#  'confection',
#  'dessert',
#  'egg dish',
#  'fish dish',
#  'fruit',
#  'herb',
#  'lamb dish',
#  'liquor',
#  'pasta and noodle dish',
#  'pastry',
#  'pie',
#  'pork dish',
#  'potato dish',
#  'pudding',
#  'rice dish',
#  'salad',
#  'sandwich',
#  'sauce',
#  'sausage',
#  'snack',
#  'soft drink',
#  'soup',
#  'spice',
#  'stew',
#  'vegetable']

# %%
default_country = 'AU'
default_category = 'beef dish'

# %%
alpha_baseline = 'intervention_flag:year[T.2020]'
beta_baseline = 'intervention_flag:k:year[T.2020]'
gamma_baseline = 'intervention_flag:np.power(k, 2):year[T.2020]'

# %%
def get_standard_error_sum(covariates):
    '''
    #95CI is approximated with +- 2 sum_variance_standard_error
    '''
    
    #get the variance covariance matrix
    vcov = result_interactions.cov_params()\
        .loc[covariates,covariates].values
    
    #calculate the sum of all pair wise covariances by summing up
    m_sum = np.sum(vcov)
    
    #variance of a sum of variables is the square root
    return np.sqrt((m_sum))

# %%
list_results = []



for country in full_names.keys():
    for c in cats:
        
        entry = {}
        entry['country']  = country
        entry['category'] = c
        
        suffix_country = (':C(country)[T.'+country+']')
        suffix_category = (':C(category)[T.'+c+']')
        
        if country == default_country and c == default_category:
            
            total_alpha = (result_interactions.params[alpha_baseline])
            total_alpha_error = (result_interactions.bse[alpha_baseline])
            
            total_beta = (result_interactions.params[beta_baseline])
            total_beta_error = (result_interactions.bse[beta_baseline])
            
            total_gamma = (result_interactions.params[gamma_baseline])
            total_gamma_error = (result_interactions.bse[gamma_baseline])
            
        elif country == default_country and c != default_category:
            
            total_alpha = (result_interactions.params[alpha_baseline]) \
                    + (result_interactions.params[alpha_baseline + suffix_category]) 
            total_alpha_error = (get_standard_error_sum([alpha_baseline, 
                                                         alpha_baseline + suffix_category]))
            
            total_beta = (result_interactions.params[beta_baseline]) \
                    + (result_interactions.params[beta_baseline + suffix_category]) 
            total_beta_error = (get_standard_error_sum([beta_baseline, 
                                                         beta_baseline + suffix_category]))
            
            total_gamma = (result_interactions.params[gamma_baseline]) \
                    + (result_interactions.params[gamma_baseline + suffix_category]) 
            total_gamma_error = (get_standard_error_sum([gamma_baseline, 
                                                         gamma_baseline + suffix_category]))

        elif country != default_country and c == default_category:
            
            total_alpha = (result_interactions.params[alpha_baseline]) \
                    + (result_interactions.params[alpha_baseline + suffix_country]) 
            total_alpha_error = (get_standard_error_sum([alpha_baseline,
                                                         alpha_baseline + suffix_country]))
            
            total_beta = (result_interactions.params[beta_baseline]) \
                    + (result_interactions.params[beta_baseline + suffix_country]) 
            total_beta_error = (get_standard_error_sum([beta_baseline,
                                                         beta_baseline + suffix_country]))
            
            total_gamma = (result_interactions.params[gamma_baseline]) \
                    + (result_interactions.params[gamma_baseline + suffix_country]) 
            total_gamma_error = (get_standard_error_sum([gamma_baseline,
                                                         gamma_baseline + suffix_country]))

        else:
            total_alpha = (result_interactions.params[alpha_baseline]) \
                    + (result_interactions.params[alpha_baseline + suffix_country]) \
                    + (result_interactions.params[alpha_baseline + suffix_category]) \
                    + (result_interactions.params[alpha_baseline + suffix_country + suffix_category])
            
            total_alpha_error = (get_standard_error_sum([alpha_baseline, 
                                                         alpha_baseline + suffix_category,
                                                         alpha_baseline + suffix_country, 
                                                         alpha_baseline + suffix_country + suffix_category]))
            
            total_beta = (result_interactions.params[beta_baseline]) \
                    + (result_interactions.params[beta_baseline + suffix_country]) \
                    + (result_interactions.params[beta_baseline + suffix_category]) \
                    + (result_interactions.params[beta_baseline + suffix_country + suffix_category])
            
            total_beta_error = (get_standard_error_sum([beta_baseline, 
                                                         beta_baseline + suffix_category,
                                                         beta_baseline + suffix_country, 
                                                         beta_baseline + suffix_country + suffix_category]))
            
            total_gamma = (result_interactions.params[gamma_baseline]) \
                    + (result_interactions.params[gamma_baseline + suffix_country]) \
                    + (result_interactions.params[gamma_baseline + suffix_category]) \
                    + (result_interactions.params[gamma_baseline + suffix_country + suffix_category])
            
            total_gamma_error = (get_standard_error_sum([gamma_baseline, 
                                                         gamma_baseline + suffix_category,
                                                         gamma_baseline + suffix_country, 
                                                         gamma_baseline + suffix_country + suffix_category]))
            
        entry['alpha'] = total_alpha
        entry['alpha_ste'] = total_alpha_error
        entry['beta'] = total_beta
        entry['beta_ste'] = total_beta_error
        entry['gamma'] = total_gamma
        entry['gamma_ste'] = total_gamma_error
        
        list_results.append(entry)

# %%
df_results = pd.DataFrame(list_results)

# %%
df_results
# Out:
#     country    category     alpha  alpha_ste      beta  beta_ste     gamma  \
# 0        AU     dessert  0.475572   0.110488 -0.053842  0.023623 -0.001281
# 1        AU  soft drink  0.258759   0.081500  0.000434  0.026456  0.000873
# 2        AU   rice dish  0.335854   0.069952  0.034397  0.016898  0.003229
# 3        AU        soup  0.049171   0.116642 -0.027825  0.030222  0.001920
# 4        AU       spice  0.320056   0.069460 -0.036825  0.013398 -0.001019
# ..      ...         ...       ...        ...       ...       ...       ...
# 379      US    sandwich  0.058558   0.116014  0.113880  0.040253  0.008543
# 380      US        cake  0.533544   0.101017  0.020858  0.025023  0.004970
# 381      US     sausage  0.265599   0.056320 -0.022746  0.020366 -0.000071
# 382      US      pastry  0.926028   0.190772 -0.108635  0.056123 -0.001376
# 383      US     pudding  0.477813   0.117525 -0.027246  0.023571  0.001437
#
#      gamma_ste
# 0     0.001622
# 1     0.002166
# 2     0.001264
# 3     0.002165
# 4     0.000949
# ..         ...
# 379   0.003402
# 380   0.001999
# 381   0.001713
# 382   0.004494
# 383   0.001745
#
# [384 rows x 8 columns]

# %% [markdown]
# ## 1. For all categories, show alpha in different countries

# %%
cats_sorted = list(df_results.groupby('category')['alpha'].agg('mean').sort_values(ascending = False).index)
countries_sorted = list(df_results.groupby('country')['alpha'].\
     agg('mean').sort_values(ascending = False).index)

# %%
sorterIndex = dict(zip(countries_sorted, range(len(countries_sorted))))

def sort_pd(key=None,reverse=False):
    def sorter(series):
        series_list = list(series)
        return [series_list.index(i) 
           for i in sorted(series_list,key=key,reverse=reverse)]
    return sorter

sort_by_custom_dict = sort_pd(key=sorterIndex.get)

# %%
fig, axes = plt.subplots(8,4, figsize = (10,12), sharey = True)

for cnt,c in enumerate(cats_sorted):
    sbplt = axes[math.floor(cnt/4), cnt%4]
    x = df_results.loc[df_results['category'] == c].iloc[sort_by_custom_dict(df_results.loc[df_results['category'] == c]['country'])][['alpha','country','alpha_ste']]
    
    colors_bars = []
    for i in range(12):
        if x['alpha'].values[i]>0 and x['alpha'].values[i]-2*x['alpha_ste'].values[i]>0:
            colors_bars.append('darkmagenta')
        elif x['alpha'].values[i]<0 and x['alpha'].values[i]+2*x['alpha_ste'].values[i]<0:
            colors_bars.append('darkgoldenrod')
        else:
            colors_bars.append('gray')
            
    #sbplt.bar(range(12),x['alpha'].apply(lambda x: np.exp(x)-1), yerr = 2*x['alpha_ste'].apply(lambda x: np.exp(x)-1), color = colors_bars)
    
    sbplt.bar(range(12),x['alpha'].apply(lambda x: np.exp(x)-1),
            #here we convert errors back to linear scale
            yerr = np.array([x['alpha'].apply(lambda x: np.exp(x)-1) - (x['alpha']-2*x['alpha_ste']).apply(lambda x: np.exp(x)-1),
                            (x['alpha']+2*x['alpha_ste']).apply(lambda x: np.exp(x)-1) - x['alpha'].apply(lambda x: np.exp(x)-1)]), 
            color = colors_bars)
    
    sbplt.set_xticks(range(12))
    sbplt.set_xticklabels(x['country'], fontsize= 8)
    sbplt.set_title(c)
    
    sbplt.set_yticks([-1,0,1,2,3])
    sbplt.set_yticklabels(["-100%","0","+100%","+200%","+300%"])
    sbplt.set_ylim([-1,4])

#fig.suptitle("α", position = (0.5, 1.05))
plt.tight_layout()

# %% [markdown]
# ## 2. In all countries, show alpha in different cats

# %%
sorterIndex = dict(zip(cats_sorted, range(len(cats_sorted))))

def sort_pd(key=None,reverse=False):
    def sorter(series):
        series_list = list(series)
        return [series_list.index(i) 
           for i in sorted(series_list,key=key,reverse=reverse)]
    return sorter

sort_by_custom_dict = sort_pd(key=sorterIndex.get)

# %%
fig, axes = plt.subplots(12,1, figsize = (8,17), sharey = True)

for cnt,country in enumerate(countries_sorted):    
    sbplt = axes[cnt]
    
    x = df_results.loc[df_results['country'] == country].iloc[sort_by_custom_dict(df_results.loc[df_results['country'] == country]['category'])][['alpha','category','alpha_ste']]
    #x = df_results.loc[df_results['country'] == country].sort_values(by='category', ascending = True)[['alpha','category','alpha_ste']]
    
    colors_bars = []
    for i in range(32):
        if x['alpha'].values[i]>0 and x['alpha'].values[i]-2*x['alpha_ste'].values[i]>0:
            colors_bars.append('darkmagenta')
        elif x['alpha'].values[i]<0 and x['alpha'].values[i]+2*x['alpha_ste'].values[i]<0:
            colors_bars.append('darkgoldenrod')
        else:
            colors_bars.append('gray')
            
            
    sbplt.bar(range(32),x['alpha'].apply(lambda x: np.exp(x)-1),
            #here we convert errors back to linear scale
            yerr = np.array([x['alpha'].apply(lambda x: np.exp(x)-1) - (x['alpha']-2*x['alpha_ste']).apply(lambda x: np.exp(x)-1),
                            (x['alpha']+2*x['alpha_ste']).apply(lambda x: np.exp(x)-1) - x['alpha'].apply(lambda x: np.exp(x)-1)]), 
            color = colors_bars
           )
    
    sbplt.set_ylim([-1,4])

    sbplt.set_xticks(range(32))
    
    if cnt == 11:
        sbplt.set_xticklabels(x['category'], fontsize= 10, rotation = 90)
    else:
        sbplt.set_xticklabels([])

    sbplt.set_title(full_names[country])

    sbplt.set_yticks([-1,0,1,2,3])
    sbplt.set_yticklabels(["-100%","0","+100%","+200%","+300%"])
    sbplt.set_ylim([-1,4])
    
    sbplt.grid(axis = 'x')


#fig.suptitle("α", position = (0.5, 1))
plt.tight_layout()

# %%
fig, axes = plt.subplots(12,1, figsize = (8,17), sharey = True)

for cnt,country in enumerate(countries_sorted):    
    sbplt = axes[cnt]
    
    #x = df_results.loc[df_results['country'] == country].iloc[sort_by_custom_dict(df_results.loc[df_results['country'] == country]['category'])][['alpha','category','alpha_ste']]
    x = df_results.loc[df_results['country'] == country].sort_values(by='category', ascending = True)[['alpha','category','alpha_ste']]
    
    colors_bars = []
    for i in range(32):
        if x['alpha'].values[i]>0 and x['alpha'].values[i]-2*x['alpha_ste'].values[i]>0:
            colors_bars.append('darkmagenta')
        elif x['alpha'].values[i]<0 and x['alpha'].values[i]+2*x['alpha_ste'].values[i]<0:
            colors_bars.append('darkgoldenrod')
        else:
            colors_bars.append('gray')
            
            
    sbplt.bar(range(32),x['alpha'].apply(lambda x: np.exp(x)-1),
            #here we convert errors back to linear scale
            yerr = np.array([x['alpha'].apply(lambda x: np.exp(x)-1) - (x['alpha']-2*x['alpha_ste']).apply(lambda x: np.exp(x)-1),
                            (x['alpha']+2*x['alpha_ste']).apply(lambda x: np.exp(x)-1) - x['alpha'].apply(lambda x: np.exp(x)-1)]), 
            color = colors_bars
           )
    
    sbplt.set_ylim([-1,4])

    sbplt.set_xticks(range(32))
    
    if cnt == 11:
        sbplt.set_xticklabels(x['category'], fontsize= 10, rotation = 90)
    else:
        sbplt.set_xticklabels([])

    sbplt.set_title(full_names[country])

    sbplt.set_yticks([-1,0,1,2,3])
    sbplt.set_yticklabels(["-100%","0","+100%","+200%","+300%"])
    sbplt.set_ylim([-1,4])
    
    sbplt.grid(axis = 'x')


#fig.suptitle("α", position = (0.5, 1))
plt.tight_layout()

# %% [markdown]
# ## 3. Show 32x12 three bars, with sign highlighted

# %%
fig, axes = plt.subplots(12,32, figsize = (30,35), sharey = True, sharex = True)

for cnt1,country in enumerate(countries_sorted):   
    for cnt2,cat in enumerate(cats_sorted):
        sbplt = axes[cnt1,cnt2]
        x = df_results.loc[(df_results['country'] == country) & (df_results['category'] == cat)]
        colors_bars = []
        significance = []
        if x['alpha'].values[0]>0 and x['alpha'].values[0]-2*x['alpha_ste'].values[0]>0:
            colors_bars.append('darkmagenta')
            significance.append('*')
        elif x['alpha'].values[0]<0 and x['alpha'].values[0]+2*x['alpha_ste'].values[0]<0:
            colors_bars.append('darkgoldenrod')
            significance.append('*')
        else:
            colors_bars.append('gray')
            significance.append('')
        if x['beta'].values[0]>0 and x['beta'].values[0]-2*x['beta_ste'].values[0]>0:
            colors_bars.append('darkmagenta')
            significance.append('*')
        elif x['beta'].values[0]<0 and x['beta'].values[0]+2*x['beta_ste'].values[0]<0:
            colors_bars.append('darkgoldenrod')
            significance.append('*')
        else:
            colors_bars.append('gray')
            significance.append('')
        if x['gamma'].values[0]>0 and x['gamma'].values[0]-2*x['gamma_ste'].values[0]>0:
            colors_bars.append('darkmagenta')
            significance.append('*')
        elif x['gamma'].values[0]<0 and x['gamma'].values[0]+2*x['gamma_ste'].values[0]<0:
            colors_bars.append('darkgoldenrod')
            significance.append('*')
        else:
            colors_bars.append('gray')
            significance.append('')


        sbplt.barh(range(3), 
                 np.array([x['alpha'].apply(lambda x: np.exp(x)-1).iloc[0],
                              x['beta'].apply(lambda x: np.exp(x)-1).iloc[0],
                              x['gamma'].apply(lambda x: np.exp(x)-1).iloc[0]])[::-1], color = colors_bars[::-1])

        sbplt.set_xlim([-1,4])
        sbplt.set_ylim([-0.5,2.5])
        sbplt.set_yticks([])
        sbplt.set_xticks([])
        sbplt.set_yticklabels([])
        sbplt.set_xticklabels([])
        if cnt1 == 11:
            sbplt.set_xlabel(cat, rotation = 90, fontsize= 10)
        if cnt2 == 0:
            sbplt.set_ylabel(full_names[country]+10*'  ', rotation = 0, fontsize= 10)
        
        sbplt.vlines(0,-0.5,2.5)
        sbplt.spines['right'].set_visible(False)
        sbplt.spines['top'].set_visible(False)
        sbplt.spines['left'].set_visible(False)
        sbplt.spines['bottom'].set_visible(False)
        
        sbplt.set_title('α='+str(round(x['alpha'].apply(lambda x: np.exp(x)-1).iloc[0],2))+significance[0]+
                        ',\n β='+str(round(x['beta'].apply(lambda x: np.exp(x)-1).iloc[0],2)) +significance[1]+
                       ',\n γ='+str(round(x['gamma'].apply(lambda x: np.exp(x)-1).iloc[0],2))+significance[2], fontsize= 10)

plt.tight_layout()
